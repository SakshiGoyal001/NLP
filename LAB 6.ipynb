# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %%
# Read in the corpus, including punctuation!
import pandas as pd
data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                         transcript  \
# DESPICABLE ME 3  In the animated adventure Despicable Me 3, Fel...
# ELEMENTAL        The film journeys alongside an unlikely pair, ...
# KLAUS            When Jesper (Jason Schwartzman) distinguishes ...
# THE BOSS BABY    Tim and his Boss Baby little bro Ted have beco...
# THE MONKEY KING  Inspired by an epic Chinese tale, THE MONKEY K...
#
#                                              full_name
# DESPICABLE ME 3                      ELEMENTAL (2023)
# ELEMENTAL                       THE MONKEY KING (2023)
# KLAUS                           DESPICABLE ME 3 (2017)
# THE BOSS BABY                             KLAUS (2019)
# THE MONKEY KING  THE BOSS BABY: FAMILY BUSINESS (2021)

# %%
# Extract only Ali Wong's text
#extracting Masters of the air text
The_monkey_king_text = data.transcript.loc['THE MONKEY KING']
The_monkey_king_text[:200]
# Out:
# 'Inspired by an epic Chinese tale, THE MONKEY KING is an action-packed family comedy that follows a charismatic Monkey (Jimmy O. Yang) and his magical fighting Stick on an epic quest for victory over 1'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):

    words = text.split(' ')
    
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
def build_markov_chain(text):
    words = text.split()  # Split the text into individual words
    chain = {}
    for i in range(len(words) - 1):
        current_word = words[i]
        next_word = words[i + 1]
        if current_word in chain:
            chain[current_word].append(next_word)
        else:
            chain[current_word] = [next_word]
    return chain

# %%
# Create the dictionary for Ali's routine, take a look at it
The_monkey_king_dict = build_markov_chain(The_monkey_king_text)
The_monkey_king_dict
# Out:
# {'Inspired': ['by'],
#  'by': ['an',
#   'the',
#   'those',
#   'one',
#   'a',
#   'eating',
#   'night,',
#   'lending',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'sunset.',
#   'everyone.',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm,',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm',
#   'storm'],
#  'an': ['epic',
#   'action-packed',
#   'epic',
#   'eccentric',
#   'uncontrollable',
#   'important',
#   'insignificant',
#   'Immortal',
#   'accomplishment.',
#   'Immortal',
#   'insignificant,',
#   'all-access',
#   'assistant.',
#   'original!',
#   'enchanted',
#   'enchanted',
#   'old',
#   'immortal',
#   'assist.',
#   'ancient',
#   'evil',
#   'illustrious'],
#  'epic': ['Chinese', 'quest'],
#  'Chinese': ['tale,'],
#  'tale,': ['THE'],
#  'THE': ['MONKEY'],
#  'MONKEY': ['KING'],
#  'KING': ['is'],
#  'is': ['an',
#   'a',
#   'meant',
#   'an',
#   'here!',
#   'me!',
#   'happening?',
#   'it?',
#   'brave',
#   'everyone?',
#   'your',
#   'but',
#   'outside.',
#   'Lin.',
#   'the',
#   'mine!',
#   'not',
#   'not',
#   'gone.',
#   'me.',
#   'you.',
#   'recorded',
#   'a',
#   'bad.',
#   'new',
#   'The',
#   'this?',
#   'getting',
#   'the',
#   'she?',
#   'more.',
#   'in',
#   'definitely',
#   'definitely',
#   'going',
#   'also',
#   'coming.',
#   'dying.',
#   'dying.',
#   'over.',
#   'so',
#   'it',
#   'making',
#   'my',
#   'it?',
#   'the',
#   'the',
#   'so',
#   'where',
#   'still',
#   'ready,',
#   'back.',
#   'goodbye.',
#   'brave',
#   'warmly',
#   'offered'],
#  'action-packed': ['family'],
#  'family': ['comedy', 'name?', 'history.', 'is', 'and'],
#  'comedy': ['that'],
#  'that': ['follows',
#   'sound',
#   'would',
#   'thing.',
#   'a',
#   'thing.',
#   'stone',
#   'way!',
#   'will',
#   'out!',
#   'stick?',
#   'armor.',
#   'right,',
#   'way.',
#   'scroll.',
#   'book!',
#   'was',
#   'in',
#   'too.',
#   'fancy',
#   'I',
#   'tree.',
#   'tree.',
#   'tree’s',
#   'are',
#   'glowing',
#   'stick.',
#   'all',
#   'wasn’t',
#   'the',
#   'old',
#   'away',
#   'way?',
#   'water?',
#   'can',
#   'monkey.',
#   'means.',
#   'even',
#   'her'],
#  'follows': ['a'],
#  'a': ['charismatic',
#   'magical',
#   'powerful',
#   'powerful',
#   'ten-foot',
#   'world',
#   'weapon.',
#   'quest',
#   'little',
#   'song.',
#   'monkey?',
#   'call',
#   'lot',
#   'king.',
#   'stick.',
#   'guy!',
#   'bath!',
#   'weapon.',
#   'stick.',
#   'lookout.',
#   'nice',
#   'tiny',
#   'selfish,',
#   'demon.',
#   'hundred',
#   'mighty',
#   'bit',
#   'hunk?',
#   'hero?',
#   'kick-pole',
#   'spinning',
#   'monkey',
#   'fancy',
#   'village?',
#   'demon',
#   'hundred',
#   '35-piece',
#   'huge',
#   'poor',
#   'grand',
#   'street',
#   'big,',
#   'hero.',
#   'Red',
#   'little',
#   'team!',
#   'lowly',
#   'tiny',
#   'difference',
#   'scroll',
#   'word.',
#   'song.”',
#   'handsome',
#   'little',
#   'thief!',
#   'lightning',
#   'ring',
#   'tiny',
#   'big',
#   'tiny',
#   'rock.',
#   'bad',
#   'ghost.',
#   'live',
#   'quick',
#   'cliff',
#   'hole',
#   'house',
#   'guy.',
#   'teammate',
#   'rock.',
#   'rock',
#   'part',
#   'kind!',
#   'teammate',
#   'pebble.',
#   'magical',
#   'while.',
#   'book',
#   'four,',
#   'deal.',
#   'rainstorm?',
#   'mere',
#   'presumptuous',
#   'deal',
#   'certain',
#   'fool.',
#   'little',
#   'few',
#   'brown.',
#   'glowing',
#   'poison',
#   'bath',
#   'scared',
#   'little',
#   'god?',
#   'bummer.',
#   'spoon',
#   'pebble.',
#   'drought.',
#   'thief.',
#   'god.',
#   'tiny',
#   'starving',
#   'mortal.',
#   'difference.',
#   'difference,',
#   'challenge.',
#   'big',
#   'momentary',
#   'warm',
#   'little',
#   'dermatology',
#   'raisin',
#   'scheme',
#   'new',
#   'mess?',
#   'challenge',
#   'long',
#   'second.',
#   'rock,',
#   'little',
#   'place',
#   'rock,',
#   'difference.',
#   'little',
#   'big',
#   'mighty',
#   'bit',
#   'hunk?',
#   'big',
#   'vision',
#   'plan',
#   'machine',
#   'big',
#   'scheme',
#   'campaign',
#   'second',
#   'woman',
#   'new',
#   'traveling',
#   'dangerous',
#   'chance',
#   'colleague',
#   'dark',
#   'week'],
#  'charismatic': ['Monkey'],
#  'Monkey': ['(Jimmy',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King.',
#   'King?',
#   'King?',
#   'King,',
#   'King!',
#   'King’s',
#   'King',
#   'King’s',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King',
#   'King',
#   'King!',
#   'King.',
#   'King!',
#   'King',
#   'King!',
#   'King',
#   'King.',
#   'punching-bag!',
#   'King',
#   'King!',
#   'King!',
#   'King,',
#   'King,',
#   'King',
#   'King.',
#   'King,',
#   'King',
#   'King’s',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King!',
#   'King'],
#  '(Jimmy': ['O.'],
#  'O.': ['Yang)'],
#  'Yang)': ['and'],
#  'and': ['his',
#   'Monkey’s',
#   'kings',
#   'dragons',
#   'we',
#   'Lord',
#   'order.',
#   'shrieks]',
#   'grunts]',
#   'woe',
#   'keep',
#   'yells]',
#   'gasps]',
#   'adore?',
#   'spunky',
#   'I’m',
#   'your',
#   'the',
#   'I’ll',
#   'bow',
#   'weapon-bearer.',
#   'take',
#   'lyrics',
#   'adore?',
#   'all',
#   'still',
#   'you’re',
#   'it',
#   'groans]',
#   'Death.',
#   'guess',
#   'learn,',
#   'Death',
#   'I',
#   'everything.',
#   'you',
#   'trusted',
#   'cunning.',
#   'take',
#   'give',
#   'pay',
#   'whimpers]',
#   'adore?',
#   'sighs]',
#   'you',
#   'Babbo',
#   'Babbo',
#   'mind',
#   'snores]',
#   'yells]',
#   'whack',
#   'they’ll',
#   'groans]',
#   'go!',
#   'give',
#   'Stick',
#   'heaven',
#   'Benbo',
#   'we’ll…',
#   'the',
#   'tentacles',
#   'Benbo]',
#   'inferior',
#   'highlands',
#   'yells]',
#   'I’ll',
#   'Stick',
#   'Wangmu',
#   'self-reflection.',
#   'all',
#   'did',
#   'you',
#   'adore?',
#   'spunky',
#   'highlands',
#   'Benbo]',
#   'highlands',
#   'Babbo]',
#   'Babbo]',
#   'highlands',
#   'the',
#   'highlands',
#   'Babbo]',
#   'continue',
#   'powerless.',
#   'old',
#   'save',
#   'horrifying…',
#   'the'],
#  'his': ['magical',
#   'eyes?',
#   'way.',
#   'grasp.',
#   'face.',
#   'lordship.',
#   'tub.',
#   'trust,',
#   'stick.',
#   'sight.',
#   'assistant.',
#   'stick.',
#   'stick',
#   'breath',
#   'world',
#   'rashy.',
#   'weakness.',
#   'own',
#   'way.',
#   'mother',
#   'family'],
#  'magical': ['fighting', 'rock', 'peach', 'fruit,'],
#  'fighting': ['Stick'],
#  'Stick': ['on', 'is', 'to', 'are', 'back.', 'laugh]'],
#  'on': ['an',
#   'Earth?',
#   'a',
#   'their',
#   'their',
#   'it,',
#   'your',
#   'me,',
#   'the',
#   'my',
#   'my',
#   'a',
#   'each',
#   'about?',
#   'everlasting',
#   'me.',
#   'the',
#   'weekends?',
#   'your',
#   'Earth.',
#   'the',
#   'all',
#   'their',
#   'a'],
#  'quest': ['for', 'for', 'has'],
#  'for': ['victory',
#   'us,',
#   'the',
#   'me?',
#   'the',
#   'the',
#   'the',
#   'stopping',
#   'my',
#   'him?',
#   'free.',
#   'number',
#   'the',
#   'ten',
#   'applause.”',
#   'your',
#   'hell,',
#   'answering',
#   'me?',
#   'you!',
#   'some',
#   'me,',
#   'you.',
#   'your',
#   'making',
#   'more,',
#   'me.',
#   'me!',
#   'new',
#   'way',
#   'your',
#   'the',
#   'high',
#   'the',
#   'you,',
#   'a',
#   'everything.',
#   'me',
#   'the',
#   '♪',
#   '♪',
#   'his'],
#  'victory': ['over', 'party.', 'speech'],
#  'over': ['100', 'earthly', 'the', 'here.', 'all'],
#  '100': ['demons,'],
#  'demons,': ['an'],
#  'eccentric': ['Dragon'],
#  'Dragon': ['King',
#   'King.',
#   'King.',
#   'King!',
#   'King?',
#   'King',
#   'King?',
#   'King',
#   'King!',
#   'King,',
#   'King…',
#   'King'],
#  'King': ['(Bowen',
#   'gasps',
#   'grunts',
#   'yells]',
#   'grunts]',
#   'grunts]',
#   'laughs]',
#   'laughs]',
#   'yells]',
#   'laughs]',
#   'laughs]',
#   'reigns',
#   'laughs]',
#   'sighs',
#   'coughs]',
#   'sighs]',
#   'sighs]',
#   'reigns',
#   'groans]',
#   'here!',
#   'grunts]',
#   'reigns',
#   'grunts]',
#   'grunts]',
#   'laughs]',
#   'laughs]',
#   'laughs]',
#   'yelps]',
#   'yells]',
#   'laughs]',
#   'grunts]',
#   'grunts]',
#   'giggles]',
#   'gulps]',
#   'snores]',
#   'snores]',
#   'reigns',
#   'grunts]',
#   'grunts]',
#   'grunts]',
#   'laughs]',
#   'screeches]',
#   'laughs]',
#   'shrieks]',
#   'shrieks]',
#   'laughs]',
#   'shrieks]',
#   'whimpers]',
#   'bawls]',
#   'mewls]',
#   'whimpers]',
#   'grunts]',
#   'yells]',
#   'screams',
#   'groans]',
#   'yells]',
#   'does,',
#   'just…',
#   'can',
#   'growls]',
#   'laughs]',
#   'laughs',
#   'grunts]',
#   'laughs]',
#   'gasps',
#   'grunts]',
#   'yells]',
#   'grunts]',
#   'yells]',
#   'clones',
#   'laughs]',
#   'snarls]',
#   'groans]',
#   'laughs]',
#   'laughs]',
#   'yells]',
#   'laughs]',
#   'grunts]',
#   'laughs',
#   'laughs]',
#   'grunts]',
#   'groans]',
#   'and',
#   'grunts]',
#   'yells',
#   'yells]',
#   'groans]',
#   'yells]',
#   'squeals]',
#   'reigns',
#   'yells]',
#   'laughs]',
#   'laughs]',
#   'laughs]',
#   'growls]',
#   'growls]',
#   'yells]',
#   'laughs]',
#   'is',
#   'laughs]',
#   'laughs]',
#   'sighs]',
#   'gasps]',
#   'yells]',
#   'yells]',
#   'strains]',
#   'reigns',
#   'panting]',
#   'laughs]',
#   'coming',
#   'stole'],
#  '(Bowen': ['Yang),'],
#  'Yang),': ['and'],
#  'Monkey’s': ['greatest', 'gonna'],
#  'greatest': ['foe', 'storm'],
#  'foe': ['of'],
#  'of': ['all',
#   'years,',
#   'the',
#   'the',
#   'him.',
#   'me.',
#   'the',
#   'rules',
#   'my',
#   'the',
#   'Havoc',
#   'hero?',
#   'Havoc.',
#   'the',
#   'style.',
#   'time.',
#   'course,',
#   'the',
#   'damage',
#   'us.',
#   'the',
#   'you.',
#   'a',
#   'you.',
#   'you',
#   'the',
#   'him.',
#   'course',
#   'no',
#   'solid',
#   'year.',
#   'the…',
#   'the',
#   'the',
#   'some',
#   'the',
#   'Life',
#   'Infinite',
#   'the',
#   'all',
#   'Ridiculous',
#   'hell.',
#   'a',
#   'doom!',
#   'this.',
#   'a',
#   'us.',
#   'old',
#   'Everlasting',
#   'Everlasting',
#   'Weather.',
#   'his',
#   'Everlasting',
#   'mine',
#   'Ridiculous',
#   'my',
#   'a',
#   'the',
#   'magic',
#   'Everlasting',
#   'immortality',
#   'you',
#   'us,',
#   'season.',
#   'trap?',
#   'Immortality.”',
#   'heaven.',
#   'Immortality.',
#   'instant',
#   'her.',
#   'chi.',
#   'chi',
#   'moon',
#   'peach.',
#   'you',
#   'us!',
#   'here!',
#   'heaven.',
#   'so',
#   'honor',
#   'drowning',
#   'the',
#   'Desperation.',
#   'you!',
#   'heaven!',
#   'the',
#   'you.',
#   'heaven',
#   'the',
#   'meditation',
#   'being',
#   'all',
#   'control.',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'vengeance',
#   'an',
#   'devout',
#   'providing',
#   'the'],
#  'all': ['—his',
#   'scared.',
#   'alone.',
#   'love',
#   'love',
#   'these',
#   'goes',
#   'these',
#   'alone?',
#   'your',
#   'cleared',
#   'right.',
#   'the',
#   'the',
#   'alone.',
#   'like,',
#   'the',
#   'over.',
#   'of',
#   'the',
#   'the',
#   'you',
#   'alone.',
#   'love',
#   'the',
#   'gonna'],
#  '—his': ['own'],
#  'own': ['ego!', 'claws,', 'assistant?', 'way.'],
#  'ego!': ['*'],
#  '*': ['*', '*', '[mysterious', 'Name*'],
#  '[mysterious': ['music', 'music', 'pipe', 'music', 'music', 'music', 'music'],
#  'music': ['plays]',
#   'crescendos]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'crescendos]',
#   'plays]',
#   'crescendos]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'continues]',
#   'continues]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'crescendos]',
#   'chimes]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'crescendos]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'continues]',
#   'plays]',
#   'crescendos]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'fades]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'fades]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'continues]',
#   'continues]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'continues]',
#   'plays]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'continues]',
#   'continues]',
#   'continues]',
#   'continues]',
#   'continues]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]',
#   'plays]'],
#  'plays]': ['[narrator]',
#   '[giggles]',
#   '[monkey',
#   'Ah!',
#   '[monkeys',
#   '[monkey',
#   '[elder',
#   '[monkey]',
#   '[grunts]',
#   '[monkey',
#   '[baby',
#   '[henchman',
#   'Wow!',
#   '[monkey',
#   'I',
#   '[monkey',
#   '[monkey',
#   'Come',
#   '[demon',
#   '[cat',
#   '[screeching]',
#   'Okay,',
#   '[Monkey',
#   'Ooh,',
#   'Stick,',
#   '[henchmen',
#   'Of',
#   '[Lin',
#   '[Monkey',
#   'Even',
#   'What’s',
#   '[Monkey',
#   'This',
#   'Aw,',
#   '♪',
#   '[Dragon',
#   'Hm.',
#   '[Monkey',
#   '[whimpers]',
#   'Sorry,',
#   '[Monkey',
#   'I',
#   'What?',
#   '[panting]',
#   'Don’t',
#   '[Dragon',
#   '[Monkey',
#   '♪',
#   'Monkey!',
#   '[Monkey',
#   'Why',
#   '[Stick',
#   'Stick?',
#   '[Babbo]',
#   '[Monkey',
#   '[Jade',
#   'What',
#   '[cat',
#   'He’s',
#   'Hey,',
#   '[Lin',
#   '[Lin]',
#   'Monkey,',
#   '[intriguing',
#   '[exciting',
#   '[uplifting',
#   '[gentle',
#   '[music'],
#  '[narrator]': ['For', 'Meet'],
#  'For': ['thousands', 'you,', 'years,', 'years'],
#  'thousands': ['of'],
#  'years,': ['Buddha', 'this'],
#  'Buddha': ['oversaw', 'said', 'speaks', 'closes', 'sent'],
#  'oversaw': ['the'],
#  'the': ['universe.',
#   'Immortal',
#   'sea.',
#   'gods,',
#   'rules',
#   'night',
#   'Universe',
#   'Immortals,',
#   'greatest,',
#   'one',
#   'Immortal',
#   'kitchen',
#   'back…',
#   'worst',
#   'coconut',
#   'light!',
#   'Immortal',
#   'light!',
#   'Demon',
#   'safety.',
#   'baby?',
#   'Demon',
#   'Dragon',
#   'Dragon',
#   'bottom',
#   'sea?',
#   'stage,',
#   'sweetest',
#   'dawn',
#   'mightiest,',
#   'best',
#   'column’s',
#   'greatest',
#   'world',
#   'most',
#   'ultimate',
#   'odds,',
#   'show?',
#   'grand',
#   'big',
#   'monkey',
#   'mightiest,',
#   'best',
#   'one',
#   'world.',
#   'nice',
#   'ultimate',
#   'Immortal',
#   'likes',
#   'handsome',
#   'Monkey',
#   'ape',
#   'chimp',
#   'simple',
#   'simian',
#   'top',
#   'Monkey',
#   'Simian',
#   'Legendary',
#   'double-kick',
#   'ever-popular',
#   'Immortal',
#   'real',
#   'mayor’s',
#   'demon',
#   'monkey.',
#   'horrible',
#   'Immortal',
#   'white',
#   'red',
#   'bone',
#   'guitar.',
#   'faster',
#   'Immortal',
#   'kid?',
#   'worst',
#   'kids',
#   'play?',
#   'whole',
#   'beef',
#   'monkey!',
#   'mighty',
#   'Immortal',
#   'bravest,',
#   'world',
#   'handsome',
#   'simian',
#   'top',
#   'Monkey',
#   'ape',
#   'dry',
#   'Immortal',
#   'Immortal',
#   'undersea',
#   'dragon',
#   'bottom',
#   'ocean.',
#   'middle',
#   'stick?',
#   'right',
#   'stick.',
#   'stick',
#   'right!',
#   'tub!',
#   'brake!',
#   'job?',
#   'Jade',
#   'name.',
#   'universe',
#   'sky.',
#   'Land',
#   'Dead.',
#   'part.',
#   'heck?',
#   'day',
#   'Scroll',
#   'underworld?',
#   'Life',
#   'world',
#   'living.',
#   'sacrificial',
#   'story.',
#   'hall.',
#   'middle',
#   'monkey!',
#   'beard!',
#   'bench!',
#   'bottom.',
#   'scroll,',
#   'Immortal',
#   'Monkey',
#   'book?',
#   'Enchanted',
#   'gods.',
#   'sass',
#   '“wanted”',
#   'monkey,',
#   'stick',
#   'faster',
#   'Immortal',
#   'right',
#   'moment.',
#   'attention',
#   'handsome',
#   'new',
#   'scene',
#   'tree',
#   'light',
#   'peach',
#   'fruit',
#   'tree',
#   'peach',
#   'color!',
#   'monkey',
#   'stick',
#   'magical',
#   'Orchard',
#   'magic',
#   'pollinators',
#   'protectors',
#   'nectar',
#   'peaches',
#   'tree',
#   'light',
#   'juiciest…',
#   'pages!',
#   'dark.',
#   'most',
#   'one…',
#   'dark…',
#   'tastiest',
#   'right',
#   'same',
#   'stage.',
#   'Dang',
#   'dragon!',
#   'two',
#   'peaches',
#   'face.',
#   'things',
#   'time',
#   'peaches',
#   'Immortal',
#   'real',
#   'wrong',
#   'royal',
#   'game!',
#   'Jade',
#   'ingredients',
#   'Elixir',
#   'thief’s',
#   'Immortal',
#   'Jade',
#   'Immortal',
#   'new',
#   'Monkey',
#   'day',
#   'answer.',
#   'stick',
#   'lives',
#   'only',
#   'whole',
#   'guest',
#   'help,',
#   'drought',
#   'entire',
#   'stage…',
#   'sun’s',
#   'H2O',
#   'shore?',
#   'air-breathing',
#   'skies',
#   'world',
#   'dry',
#   'world',
#   'world',
#   'big',
#   'skies',
#   'world',
#   'top',
#   'world',
#   'brave',
#   'norm',
#   'skies',
#   'whole',
#   'honor',
#   'mighty',
#   'top',
#   'hill!',
#   'only',
#   'assist,',
#   'stick!',
#   'Dragon',
#   'Royal',
#   'Buddha',
#   'giant',
#   'Great',
#   'center',
#   'universe?',
#   'kingdom',
#   'edge',
#   'universe,',
#   'Great',
#   'only',
#   'path',
#   'world',
#   'king',
#   'ways',
#   'gods',
#   'land.',
#   'West?',
#   'handsome',
#   'Monkey',
#   'ape',
#   'chimp',
#   'simple',
#   'simian',
#   'top',
#   'Monkey',
#   'skies',
#   'world',
#   'dry',
#   'world',
#   'world',
#   'world',
#   'world',
#   'world',
#   'whole',
#   'stick',
#   'plan',
#   'monkey',
#   'sand',
#   'rain',
#   'last',
#   'skies',
#   'world',
#   'dry',
#   'world',
#   'land',
#   'sky',
#   'skies',
#   'world',
#   'world',
#   'world',
#   'world',
#   'fish',
#   'pillar',
#   'world',
#   'man',
#   'plan',
#   'monkey',
#   'sand',
#   'rain',
#   'last',
#   'skies',
#   'world',
#   'dry',
#   'world',
#   'haters',
#   'dehydraters',
#   'land-walking,',
#   'skies',
#   'world',
#   'dry',
#   'world',
#   'world',
#   'world',
#   'world',
#   'world',
#   'world',
#   'corrupt',
#   'poor',
#   'discovery',
#   'world',
#   'picture-perfect',
#   'weight',
#   'myth',
#   'American',
#   'privacy',
#   'Loft.',
#   'best'],
#  'universe.': ['And', 'Compared'],
#  'And': ['the',
#   'save',
#   'five,',
#   'he',
#   'also',
#   'you',
#   'Stick.',
#   'leave',
#   'a',
#   'ten',
#   'for',
#   'Stick.',
#   'you',
#   'you,',
#   'there',
#   'now',
#   'to',
#   'this',
#   'if',
#   'you',
#   'then',
#   'now',
#   'I',
#   'my',
#   'handsome.',
#   'once',
#   'let’s',
#   'the',
#   'you',
#   'huge!',
#   'then',
#   'you',
#   'I',
#   'a',
#   'woe,',
#   'take',
#   'nobody',
#   'no',
#   'take',
#   'he',
#   'take',
#   'now',
#   'two',
#   'you',
#   'Monkey,',
#   'also',
#   'you',
#   'take',
#   'take',
#   'DK',
#   'bury',
#   'everybody',
#   'take',
#   'take',
#   'take',
#   'the',
#   'bam!',
#   'DK',
#   'bury',
#   'everybody',
#   'take',
#   'take',
#   'take',
#   'take',
#   'nobody'],
#  'Immortal': ['Ones',
#   'Ones',
#   'Ones',
#   'Ones.',
#   'One?',
#   'Ones.',
#   'Ones',
#   'Ones,',
#   'Ones.”',
#   'Ones?',
#   'Ones',
#   'Ones.',
#   'One,',
#   'Ones',
#   'Ones?',
#   'Ones.',
#   'Ones.',
#   'Ones!',
#   'Ones.'],
#  'Ones': ['in', 'at', 'in', 'know', 'can', 'together.'],
#  'in': ['heaven',
#   'hell',
#   'balance.',
#   'the',
#   'a',
#   'heaven',
#   'danger!',
#   'you.',
#   'it',
#   'it',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'hell,',
#   'hell.',
#   'my',
#   'hell?',
#   'front',
#   'the',
#   'battle.',
#   'fights,',
#   'you,',
#   'my',
#   'my',
#   'the',
#   'my',
#   'the',
#   'light,',
#   'that',
#   'the',
#   'the',
#   'the',
#   'those',
#   'the',
#   'her',
#   'the',
#   'heaven.',
#   'this',
#   'pain]',
#   'one',
#   'hell,',
#   'your',
#   'the',
#   'pain]',
#   'riddles.',
#   'about',
#   'there?',
#   'no',
#   'my',
#   'the',
#   'the'],
#  'heaven': ['and', 'are', 'in', 'will'],
#  'kings': ['in'],
#  'hell': ['watched', 'and…', 'and'],
#  'watched': ['over'],
#  'earthly': ['affairs.'],
#  'affairs.': ['Demons'],
#  'Demons': ['walked'],
#  'walked': ['among'],
#  'among': ['us,'],
#  'us,': ['and', 'it', 'we’re'],
#  'dragons': ['ruled'],
#  'ruled': ['the'],
#  'sea.': ['Everything'],
#  'Everything': ['was'],
#  'was': ['in',
#   'saying,',
#   'just',
#   'so',
#   'for',
#   'born',
#   'your',
#   'fun.',
#   'mostly',
#   'nice',
#   'just',
#   'fun.',
#   'all',
#   'you.',
#   'here.',
#   'born',
#   'to',
#   'chillin’'],
#  'balance.': ['We'],
#  'We': ['respected',
#   'have',
#   'can’t',
#   'live',
#   'can',
#   'all',
#   'could',
#   'had',
#   'all',
#   'don’t',
#   'really',
#   'went',
#   'have',
#   'carry',
#   'love',
#   'are',
#   'are',
#   'promise',
#   'can’t',
#   'gotta',
#   'really',
#   'both',
#   'helped',
#   'all',
#   'need',
#   'bring',
#   'bring'],
#  'respected': ['the'],
#  'gods,': ['and'],
#  'we': ['followed',
#   'did',
#   'can',
#   'win.',
#   'get',
#   'poor',
#   'were',
#   'know',
#   'know',
#   'took',
#   'choose',
#   'go?',
#   'get',
#   'possibly',
#   'gotta',
#   'even',
#   'made',
#   'put',
#   'were',
#   'waiting',
#   'need',
#   'were',
#   'have',
#   'do',
#   'fired?',
#   'need',
#   'show',
#   'didn’t',
#   'came',
#   'came'],
#  'followed': ['the'],
#  'rules': ['until', 'and'],
#  'until': ['the', 'the'],
#  'night': ['a', 'air.'],
#  'rock': ['gave', 'egg.'],
#  'gave': ['birth'],
#  'birth': ['to', 'I'],
#  'to': ['a',
#   'discuss.',
#   'live',
#   'the',
#   'the',
#   'free',
#   'create',
#   'make.',
#   'the',
#   'leave',
#   'those',
#   'take',
#   'the',
#   'it.',
#   'love',
#   'defeat',
#   'even',
#   'the',
#   'go.',
#   'know',
#   'come',
#   'celebrate',
#   'find',
#   'my',
#   'fall',
#   'make',
#   'witness',
#   'join',
#   'remain',
#   'the',
#   'our',
#   'move.',
#   'me.',
#   'be',
#   'the',
#   'me,',
#   'come.',
#   'next?',
#   'keep',
#   'be',
#   'die',
#   'the',
#   'the',
#   'be',
#   'defeat',
#   'hell!',
#   'draw',
#   'draw',
#   'his',
#   'be',
#   'join',
#   'put',
#   'worry',
#   'get',
#   'that',
#   'go',
#   'be',
#   'be',
#   'know',
#   'detail',
#   'next?',
#   'step',
#   'poison',
#   'knock',
#   'one.',
#   'the',
#   'take',
#   'anything.”',
#   'think',
#   'the',
#   'you?',
#   'accept',
#   'go,',
#   'taste',
#   'goof',
#   'sting!',
#   'protect',
#   'save',
#   'do',
#   'him?',
#   'take',
#   'get',
#   'the',
#   'hell',
#   'make',
#   'end',
#   'meet',
#   'borrow',
#   'do',
#   'me!',
#   'you',
#   'stop',
#   'the',
#   'the',
#   'let',
#   'stop.',
#   'leap',
#   'rule.',
#   'leave',
#   'prove',
#   'make',
#   'be',
#   'help',
#   'happen.',
#   'nothingness,',
#   'nothingness.',
#   'belong.',
#   'be',
#   'nothingness?',
#   'get',
#   'say',
#   'remind',
#   'be',
#   'release',
#   'join',
#   'the',
#   'fight?',
#   'the',
#   'find',
#   'find',
#   'systemically',
#   'protect',
#   'the',
#   'Cecilia',
#   'your'],
#  'powerful': ['being.', 'being.', 'being?', 'enough'],
#  'being.': ['[dramatic', 'He'],
#  '[dramatic': ['music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music'],
#  'crescendos]': ['[narrator]',
#   '[jaunty',
#   '[monkeys',
#   '[cuttlefish]',
#   'There’s',
#   '[Lin'],
#  'Meet': ['trouble.'],
#  'trouble.': ['[squeaks]'],
#  '[squeaks]': ['Oh.', '[jaunty'],
#  'Oh.': ['Ooh.', '[baby', '[gasps', 'So,', 'I', 'I’m', '“Full', 'Keep'],
#  'Ooh.': ['[squeaks]', 'In', 'Wha…'],
#  '[jaunty': ['music', 'music', 'music'],
#  '[giggles]': ['Okay,'],
#  'Okay,': ['okay.',
#   'imaginary',
#   'desperate',
#   'I’ll',
#   'Monkey',
#   'little',
#   'look,',
#   'you’re',
#   'let’s',
#   'Lin.',
#   'you',
#   'you'],
#  'okay.': ['Attention,', 'You’re'],
#  'Attention,': ['everyone.'],
#  'everyone.': ['We', '[grunts]', 'Places!', 'Th-The'],
#  'have': ['important',
#   'that.',
#   'a',
#   'my',
#   'to',
#   'the',
#   'done.',
#   'one.',
#   'parents,',
#   'my',
#   'one.',
#   'no',
#   'to',
#   'that',
#   'to',
#   'to',
#   'my',
#   'some',
#   'to',
#   'to',
#   'no',
#   'no',
#   'no',
#   'to',
#   'to',
#   'no',
#   'fought',
#   'the',
#   'accepted',
#   'to',
#   'a',
#   'to',
#   'found',
#   'to',
#   'awoken'],
#  'important': ['business', 'destiny.'],
#  'business': ['to'],
#  'discuss.': ['I,'],
#  'I,': ['your', 'uh,', 'sire?'],
#  'your': ['Jade',
#   'place,',
#   'insignificance.',
#   'guy.',
#   'assistant',
#   'number',
#   'stick',
#   'trap.',
#   'humble',
#   'medal.',
#   'right.',
#   'first',
#   'family',
#   'family',
#   'scrolls?',
#   'banquets.',
#   'plan.',
#   'beard',
#   'friends',
#   'eyes.',
#   'paws',
#   'rain.',
#   'drip,',
#   'audience.',
#   'marks.',
#   'own…',
#   'skin’s',
#   'help.',
#   'place',
#   'deal?',
#   'new,',
#   'way.',
#   'help.',
#   'village',
#   'people,',
#   'roof…',
#   'fins',
#   'assistant!',
#   'immortality',
#   'crimes.',
#   'hand?',
#   'way.',
#   'mountain.',
#   'number',
#   'assistant?',
#   'scroll,',
#   'e-mail',
#   'inbox!'],
#  'Jade': ['Emperor,', 'Emperor.', 'Emperor,', 'Palace?', 'Emperor', 'Palace.'],
#  'Emperor,': ['Architect', 'right?'],
#  'Architect': ['of'],
#  'Universe': ['and'],
#  'Lord': ['of'],
#  'Immortals,': ['shall'],
#  'shall': ['throw', 'take', 'devour', 'spend'],
#  'throw': ['the'],
#  'greatest,': ['most'],
#  'most': ['fantastic', 'powerful', 'spectac…', 'delicious.'],
#  'fantastic': ['banquet'],
#  'banquet': ['since'],
#  'since': ['the', 'the', 'birth', 'then'],
#  'one': ['we',
#   'little',
#   'thing',
#   'of',
#   'of',
#   'of',
#   'fan.',
#   'choice.',
#   'appreciates',
#   'of',
#   'get',
#   'job!',
#   'tree.',
#   'in',
#   'in',
#   'else',
#   'of',
#   'of',
#   'day.',
#   'thought',
#   'understands',
#   'fan.'],
#  'did': ['last',
#   'you',
#   'you',
#   'you',
#   'you?',
#   'I',
#   'you',
#   'it!',
#   'you',
#   'it.',
#   'this.',
#   'he',
#   'make',
#   'great',
#   'I'],
#  'last': ['Tuesday.', 'victim.', 'dance', 'laugh', 'dance', 'laugh'],
#  'Tuesday.': ['Doesn’t'],
#  'Doesn’t': ['that', 'he?', 'sound'],
#  'sound': ['fun,', 'like'],
#  'fun,': ['hmm?'],
#  'hmm?': ['Understood,'],
#  'Understood,': ['Your'],
#  'Your': ['Majesty.',
#   'Majesty.',
#   'recklessness',
#   'what?',
#   'Grace?',
#   'palm?',
#   'Grace.',
#   'friend’s',
#   'storm',
#   'Majesty!',
#   'email'],
#  'Majesty.': ['Now,', 'We'],
#  'Now,': ['seating', 'son,', 'son…', 'any'],
#  'seating': ['arrangements.'],
#  'arrangements.': ['Place'],
#  'Place': ['the'],
#  'at': ['my',
#   'ya.',
#   'his',
#   'me!',
#   'the',
#   'that',
#   'the',
#   'your',
#   'me.',
#   'my',
#   'the',
#   'me.',
#   'my',
#   'you.',
#   'an'],
#  'my': ['head',
#   'palm',
#   'grand',
#   'own',
#   'Stick.',
#   'ascension',
#   'trusty',
#   'innocent',
#   'snack?',
#   'presence',
#   'awesome',
#   'house!',
#   'skills',
#   'big',
#   'stick.',
#   'stick,',
#   'wrath!',
#   'stick.',
#   'exclusive',
#   'name',
#   'other',
#   'assistant,',
#   'scroll',
#   'name',
#   'scroll?',
#   'family?',
#   'way.',
#   'name',
#   'lord.',
#   'very',
#   'full',
#   'call.',
#   'possession,',
#   'grip,',
#   'back.',
#   'shoes',
#   'village,',
#   'performance',
#   'little',
#   'best',
#   'head',
#   'stick',
#   'village',
#   'tail',
#   'accomplishment.',
#   'scroll.',
#   'celebration',
#   'child.',
#   'home.',
#   'power',
#   'Stick?',
#   'clones!',
#   'poor',
#   'old',
#   'palm,',
#   'other',
#   'hand,',
#   'best',
#   'life.',
#   'promise',
#   'heart,',
#   'power'],
#  'head': ['table.', 'off.'],
#  'table.': ['Minor'],
#  'Minor': ['gods'],
#  'gods': ['by', 'probably', 'hated'],
#  'kitchen': ['in'],
#  'back…': ['[Jade'],
#  '[Jade': ['Emperor', 'Emperor', 'Emperor', 'Emperor]', 'Emperor', 'Emperor]'],
#  'Emperor': ['yells]', 'shrieks]', 'will', 'yelps]', 'yelps]'],
#  'yells]': ['[cat',
#   '[dramatic',
#   '[monkey',
#   '[baby',
#   '[Stick',
#   '[heavy',
#   'Huh!',
#   '[Monkey',
#   'Whoa!',
#   'Monkey,',
#   '[Yama',
#   'Did',
#   'Is',
#   'Um,',
#   'Perfect.',
#   'Ha',
#   '[laughs]',
#   'He’s',
#   '[triumphant',
#   'What',
#   '[Dragon',
#   '[Dragon',
#   '[laughs]',
#   '[Dragon',
#   '[Dragon',
#   '[Dragon',
#   '[Yama',
#   '[Wangmu',
#   'No,',
#   '[Stick',
#   'Ha!'],
#  '[cat': ['meows]', 'meows]', 'meows]', 'yelps]'],
#  'meows]': ['[cat', '[monkey', '[demon'],
#  '[monkey': ['screeches]',
#   'grunts]',
#   'cackles]',
#   'mother',
#   'sighs]',
#   'mother',
#   'laughs]',
#   'grunts]',
#   'laughs]',
#   'mother',
#   'growls]',
#   'gasps]',
#   'grunts]',
#   'yells]',
#   'laughs]',
#   '1',
#   '2]',
#   '3]',
#   'panting]',
#   'yells]',
#   'groans]',
#   'grunts]',
#   'grunts]',
#   'gasps]',
#   'yells]',
#   'gasps]',
#   'grunts]',
#   'gasps]',
#   'gasps]',
#   'grunts]',
#   'grunts]',
#   'yells]',
#   'panting]',
#   'grunts]',
#   'laughs]'],
#  'screeches]': ['What', 'A', '[Lin'],
#  'What': ['on',
#   'are',
#   'is',
#   'is',
#   'a',
#   'do',
#   'are',
#   'do',
#   'are',
#   'took',
#   'a',
#   'an',
#   'am',
#   'the',
#   'are',
#   'a',
#   'teammate?',
#   'is',
#   'the…',
#   'a',
#   'should',
#   'just…',
#   'just',
#   'are',
#   'are',
#   'the…',
#   'else?',
#   'a',
#   'are',
#   'are',
#   'do',
#   'is',
#   'is',
#   'gives?',
#   'did',
#   'does',
#   'we',
#   'we'],
#  'Earth?': ['[laughs]'],
#  '[laughs]': ['[squeals]',
#   '[grunts]',
#   '[exciting',
#   '[Monkey',
#   '[Red',
#   'Hey,',
#   'Huh.',
#   '[Monkey',
#   '[shudders]',
#   'My',
#   'I',
#   'No!',
#   'Benbo,',
#   'Okay.',
#   'What',
#   'All',
#   '[Babbo',
#   '[Lin',
#   'Aw,',
#   'First,',
#   'Immortality',
#   'You',
#   'Uh,',
#   '[Monkey',
#   'Whoa!',
#   '[gasps]',
#   '[Stick',
#   'Hm.',
#   'I',
#   '[Stick',
#   '♪'],
#  '[squeals]': ['[monkey', 'Hm,'],
#  'grunts]': ['[squeals]',
#   'Will',
#   '[elder',
#   '[monkey',
#   '[laughs]',
#   '[demon',
#   '[tense',
#   '[Stick',
#   'Stick,',
#   'Monkey.',
#   '[dramatic',
#   '[baby',
#   '[tranquil',
#   'Uh-oh.',
#   '[Red',
#   '[tense',
#   '[grunts]',
#   'Monkey',
#   '[clones',
#   '[Monkey',
#   'Wait!',
#   'Oof!',
#   '[Monkey',
#   '[Monkey',
#   '[Lin',
#   'Woo-hoo!',
#   '[Lin',
#   '[Lin',
#   '[murmurs]',
#   '[Lin',
#   'The',
#   '[mysterious',
#   'Locked.',
#   '[Wangmu]',
#   '[Lin',
#   'What',
#   '[Monkey',
#   'I’ve',
#   '[strains]',
#   'Ah,',
#   'I’ll',
#   'Stop!',
#   '[Monkey',
#   '[Dragon',
#   '[dramatic',
#   '[Dragon'],
#  'Hm,': ['an', 'well…'],
#  'uncontrollable': ['monkey'],
#  'monkey': ['shooting',
#   'is',
#   'giggles]',
#   'squeals]',
#   'never',
#   'grunts]',
#   'groans]',
#   'growls]',
#   'is',
#   'grunts]',
#   'whimpers]',
#   'shrieks]',
#   'stole',
#   'you',
#   'who’s',
#   'whimpers]',
#   'squeals]',
#   'squeals]',
#   'squeals]',
#   'squeals]',
#   'shrieks]',
#   'scoffs]',
#   'with',
#   'heroes',
#   'would.',
#   'passes',
#   'can',
#   'heroes',
#   'from',
#   'looking',
#   '♪',
#   '♪'],
#  'shooting': ['light'],
#  'light': ['beams', 'has', 'has'],
#  'beams': ['from'],
#  'from': ['his',
#   'here.',
#   'you.',
#   'a',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'hell!',
#   'the',
#   'an',
#   'a',
#   'smashing',
#   'my',
#   'a',
#   'a',
#   'a',
#   'a',
#   'the'],
#  'eyes?': ['He’s'],
#  'He’s': ['probably',
#   'the',
#   'just',
#   'the',
#   'the',
#   'mine!',
#   'still',
#   'coming',
#   'coming',
#   'not',
#   'never',
#   'coming.',
#   'coming.',
#   'coming.',
#   'not',
#   'flashy.',
#   'splashy.',
#   'taking',
#   'makin’',
#   'just',
#   'the'],
#  'probably': ['just', 'shouldn’t', 'wasn’t'],
#  'just': ['excited,',
#   'a',
#   'making',
#   'wants',
#   'gonna',
#   'kidnapped.',
#   'what',
#   'wanna',
#   'stole',
#   'have',
#   'sit',
#   'happened?',
#   'the',
#   'have',
#   'smelling',
#   'a',
#   'a',
#   'curse',
#   'a',
#   'needs',
#   'on',
#   'say?',
#   'have',
#   'happened,',
#   'a'],
#  'excited,': ['Your'],
#  'can’t': ['have',
#   'escape',
#   'play',
#   'read.',
#   'go',
#   'die',
#   'keep',
#   'do',
#   'give',
#   'fool',
#   'shame',
#   'do.',
#   'die.',
#   'catch',
#   'stop',
#   'escape'],
#  'that.': ['Get', 'Absolutely.', 'I’m'],
#  'Get': ['rid',
#   'rid',
#   'her,',
#   'it',
#   'reading.',
#   'her!',
#   'the',
#   'hammered.',
#   'your',
#   'mixing.',
#   'the'],
#  'rid': ['of', 'of'],
#  'him.': ['[deep',
#   '[tense',
#   'Well,',
#   'You',
#   '[Dragon',
#   '[Monkey',
#   '[horn',
#   'He',
#   'What?'],
#  '[deep': ['voice]', 'voice]', 'voice]', 'voice]'],
#  'voice]': ['Patience.', 'Monkey', 'I', 'But'],
#  'Patience.': ['[Jade'],
#  'shrieks]': ['Buddha!', '[dramatic', 'Come', 'Oh', '[Lin', '[Lin', '[Monkey'],
#  'Buddha!': ['I'],
#  'I': ['didn’t',
#   'mean,',
#   'was',
#   'can',
#   'know!',
#   'could…',
#   'have',
#   'demand',
#   'believe',
#   'shall',
#   'am',
#   'get',
#   'like',
#   'have',
#   'should',
#   'don’t',
#   'belong',
#   'conquered',
#   'suppose',
#   'don’t',
#   'am…',
#   'am?',
#   'mean,',
#   'am.',
#   'know',
#   'like',
#   'don’t',
#   'mean,',
#   'slay',
#   'shall',
#   'see',
#   'am',
#   'can',
#   'care!',
#   'know',
#   'will',
#   'am',
#   'offer',
#   'said',
#   'ascend!',
#   'am',
#   'didn’t.',
#   'found',
#   'reclaim',
#   'hear',
#   'do.',
#   'don’t',
#   'thought.',
#   'have',
#   'missing?',
#   'need',
#   'can',
#   'mean,',
#   'can.',
#   'can’t',
#   'probably',
#   'just',
#   'know.',
#   'said',
#   'couldn’t',
#   'mean',
#   'fell…',
#   'drowned.',
#   'can',
#   'was',
#   'must',
#   'guess.',
#   'can?',
#   'got',
#   'say,',
#   'beseech',
#   'am.',
#   'can',
#   'will',
#   'mention?',
#   'can’t',
#   'can’t',
#   'remember.',
#   'beseech',
#   'told',
#   'accept.',
#   'do?',
#   'need',
#   'value',
#   'could’ve',
#   'come.',
#   'only',
#   'lit',
#   'don’t',
#   'like',
#   'mean,',
#   'look',
#   'come.',
#   'don’t',
#   'do.',
#   'feel',
#   'know',
#   'do!',
#   'loved',
#   'fully',
#   'won’t',
#   'don’t',
#   'noticed.',
#   'couldn’t',
#   'heard',
#   'could',
#   'mean,',
#   'didn’t.',
#   'deliberately',
#   'lied',
#   'can’t',
#   'punish',
#   'shame',
#   'have',
#   'think',
#   'did',
#   'need',
#   'love',
#   'can’t',
#   'summon',
#   'can’t',
#   'am',
#   'so',
#   'admit',
#   'know!',
#   'got',
#   'die.',
#   'say',
#   'just',
#   'don’t',
#   'rip',
#   'mean,',
#   'know',
#   'read',
#   'don’t',
#   'could',
#   'dunno.',
#   'wasn’t',
#   'had',
#   'trusted',
#   'saved',
#   'saved',
#   'asked',
#   'want',
#   'had',
#   'had',
#   'have',
#   'know',
#   'have',
#   'resigned',
#   'stay',
#   'despise?',
#   'am!',
#   'take',
#   'believe',
#   'said',
#   'am',
#   'got',
#   'can',
#   'missed',
#   'get',
#   'will',
#   'did',
#   'let',
#   'do',
#   'got',
#   'have',
#   'just',
#   'really',
#   'rule!',
#   'totally',
#   'was',
#   'wanted',
#   'was',
#   'thrive!',
#   'made',
#   'awaken',
#   'came',
#   'know',
#   'really',
#   'made',
#   'really',
#   'guess',
#   'missed',
#   'guess',
#   'will.',
#   'kept',
#   'have',
#   'transform',
#   'come',
#   'was',
#   'envisioned',
#   'mean',
#   'take',
#   'accept'],
#  'didn’t': ['see', 'die.', 'succumb', 'lose', 'because', 'I?', 'do'],
#  'see': ['you', 'you,', 'a', 'this?', 'you', 'ya'],
#  'you': ['there.',
#   'let',
#   'go',
#   'will',
#   'were',
#   'could',
#   'said',
#   'need',
#   'mean',
#   'do',
#   'doing?',
#   'to',
#   'can’t',
#   'down?',
#   'know',
#   'either.',
#   'even',
#   'wanna',
#   'and',
#   'a',
#   'want?',
#   'doing?',
#   'so',
#   'challenge',
#   'gonna…',
#   'really',
#   'can',
#   'get',
#   'want',
#   'can',
#   'got',
#   'sure?',
#   'know',
#   'were',
#   'sufficiently',
#   'anyway?',
#   'and',
#   'know.',
#   'coming',
#   'doing?',
#   'cut',
#   'die?',
#   'find',
#   'don’t',
#   'flea-bitten,',
#   'half-immortal.',
#   'can',
#   'do,',
#   'blew',
#   'treat',
#   'five',
#   'forget?',
#   'please',
#   'to',
#   'dimwit!',
#   'for',
#   'please,',
#   'a',
#   'lie',
#   'have',
#   'scrumptious,',
#   'make',
#   'follow',
#   'need',
#   'have',
#   'top',
#   'are.',
#   'hear',
#   'believe',
#   'sure',
#   'get',
#   'eat',
#   'eat',
#   'should',
#   'very',
#   'gotta',
#   'realize',
#   'are',
#   'said',
#   'promised',
#   'to',
#   'won’t',
#   'really',
#   'yapping',
#   'trash',
#   'to',
#   'have',
#   'go.',
#   'now.',
#   'home.',
#   'going',
#   'were',
#   'stronger?',
#   'now.',
#   'can’t',
#   'didn’t',
#   'care.',
#   'two',
#   'sure?',
#   'won’t',
#   'could',
#   'help',
#   'or',
#   'think',
#   'wait',
#   'get',
#   'first.',
#   'said.',
#   'for',
#   'get',
#   'crazy.',
#   'can’t',
#   'oughta',
#   'die?',
#   'his',
#   'so',
#   'can',
#   'have',
#   'are',
#   'fail,',
#   'will',
#   'even',
#   'are',
#   'know?',
#   'awake',
#   'will',
#   'were',
#   'don’t',
#   'were',
#   'ever',
#   'are!',
#   'so',
#   'for',
#   'ready',
#   'wish',
#   'can’t',
#   'down?',
#   'know'],
#  'there.': ['[Buddha]', 'Wait.', '[Lin', 'Whoopsie-daisy!'],
#  '[Buddha]': ['This', 'Then', 'Enlighten', 'Monkey', 'When', 'The'],
#  'This': ['monkey',
#   'village',
#   'dump',
#   'monkey',
#   'thing',
#   'here',
#   'is',
#   'shouldn’t',
#   'one’s',
#   'was',
#   'book',
#   'could',
#   'monkey’s',
#   'one?',
#   'peach',
#   'is',
#   'old',
#   'is',
#   'monkey',
#   'is',
#   'has',
#   'ends',
#   'is',
#   'is',
#   'is',
#   'is',
#   'demon'],
#  'He': ['has',
#   'could',
#   'didn’t',
#   'got',
#   'got',
#   'doesn’t',
#   'just',
#   'only',
#   'wants',
#   'gets',
#   'just',
#   'already',
#   'never',
#   'wants',
#   'so',
#   'was',
#   'just',
#   'has',
#   'does',
#   'won’t',
#   'won’t'],
#  'has': ['an',
#   'stood',
#   'waited',
#   'ever',
#   'demons',
#   'ever',
#   'demons',
#   'invaded',
#   'two',
#   'the',
#   'the',
#   'failed,',
#   'caused',
#   'gone',
#   'goodness',
#   'needed',
#   'demons'],
#  'destiny.': ['Let'],
#  'Let': ['him', 'our', 'me'],
#  'him': ['find',
#   'leave',
#   'one.',
#   'there.',
#   'out',
#   'up.',
#   'out!',
#   'find',
#   'find',
#   'he’s',
#   'as',
#   'in',
#   'do',
#   'in',
#   'do'],
#  'find': ['his',
#   'shimmying',
#   'a',
#   'shimmying',
#   'my',
#   'happiness',
#   'his',
#   'his',
#   'shimmying',
#   'the',
#   'the'],
#  'way.': ['Very',
#   'Obviously.',
#   'Next!',
#   'We’re',
#   'You',
#   '[scoffs]',
#   '[Lin]',
#   '[Monkey'],
#  'Very': ['well.', 'well.', 'much'],
#  'well.': ['I', 'I'],
#  'mean,': ['what’s', 'of', 'this', 'yes.', 'the', 'it', 'come'],
#  'what’s': ['the', 'the', 'down?', 'wrong', 'in'],
#  'worst': ['it', 'daddy'],
#  'it': ['can',
#   'will',
#   'up',
#   'took',
#   'angrier.',
#   'now.',
#   'worse.',
#   'for',
#   'for',
#   'want?',
#   'hurt',
#   'from',
#   'work.',
#   'is.',
#   'for',
#   'at',
#   'is.',
#   'now?',
#   'made',
#   'great?',
#   'say',
#   'say?',
#   'says…',
#   'up',
#   'first.',
#   'myself,',
#   'was',
#   'say?',
#   'to',
#   'when',
#   'out',
#   'have',
#   '♪',
#   'rain',
#   'off!',
#   'now?',
#   'great?',
#   'has',
#   'myself.',
#   'all',
#   'rain',
#   '♪',
#   '♪',
#   'quick',
#   'rains,',
#   'pours',
#   '♪',
#   'rains,',
#   'pours',
#   '♪',
#   'becomes'],
#  'can': ['do,',
#   'beat',
#   'help',
#   'do',
#   'take',
#   'defeat',
#   'hold',
#   'welcome',
#   'help.',
#   'make',
#   'cross',
#   'still',
#   'tell',
#   'get',
#   'be',
#   'often',
#   'do',
#   'hold',
#   'help',
#   'help',
#   'defeat',
#   'have',
#   'swing',
#   'we'],
#  'do,': ['right?', 'don’t'],
#  'right?': ['Where',
#   '[Stick',
#   'That’s',
#   'Um,',
#   'Well,',
#   'Listen,',
#   'But',
#   'I'],
#  'Where': ['were', 'is', 'did', 'did', 'to', 'is', 'did'],
#  'were': ['we?',
#   'just',
#   'a',
#   'promised',
#   'defective.',
#   'family.',
#   'worthy',
#   'in',
#   'fake!',
#   'out',
#   'born'],
#  'we?': ['Ah,', '[Stick'],
#  'Ah,': ['dessert!', 'let’s', 'that’s', 'I'],
#  'dessert!': ['I’m'],
#  'I’m': ['thinking',
#   'actually',
#   'busy.',
#   'not',
#   'right.',
#   'the',
#   'in.',
#   'hungry!',
#   'coming!',
#   'gonna',
#   'the',
#   'not…',
#   'not',
#   'all',
#   'sorry,',
#   'an',
#   'immortal!',
#   'on',
#   'adorable!',
#   'not',
#   'still',
#   'starting',
#   'not',
#   'just',
#   'not',
#   'so',
#   'his',
#   'just',
#   'only',
#   'immortal!',
#   'one',
#   'already',
#   'busy!',
#   'immortal!',
#   'just',
#   'Lin.',
#   'listening.',
#   'gonna',
#   'the',
#   'taking',
#   'making',
#   'immortal,',
#   'not',
#   'his.',
#   'sorry.',
#   'the',
#   'busy',
#   'sure',
#   'saying',
#   'gonna'],
#  'thinking': ['a', 'of'],
#  'ten-foot': ['egg'],
#  'egg': ['tart'],
#  'tart': ['sculpture'],
#  'sculpture': ['of'],
#  'me.': ['[suspenseful',
#   'Mm-mm.',
#   'No',
#   '[girl]',
#   'Hey,',
#   'Okay?',
#   'This',
#   'You’re',
#   'Well,',
#   'Way',
#   '[Monkey',
#   'I',
#   'Monkey',
#   'What’s',
#   '[Stick',
#   'The',
#   'Now',
#   'I',
#   'Taking'],
#  '[suspenseful': ['music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music',
#   'music'],
#  'cackles]': ['[baby', 'Uh,'],
#  '[baby': ['monkey',
#   'monkey',
#   'monkey',
#   'monkey',
#   'monkey',
#   'monkey',
#   'monkey',
#   'monkey',
#   'monkey',
#   'monkey'],
#  'giggles]': ['[monkey', 'I'],
#  'mother': ['coos]', 'screeches]', 'cries]', 'and'],
#  'coos]': ['[tranquil'],
#  '[tranquil': ['music', 'music', 'music', 'music'],
#  'Ah!': ['Oh.'],
#  'squeals]': ['Oh!',
#   'Shh!',
#   '[demon',
#   '[demon',
#   '[demon',
#   'Oh!',
#   'Are',
#   '[Monkey'],
#  'Oh!': ['[monkey',
#   '[monkeys',
#   '[young',
#   'Ugh!',
#   '[laughs]',
#   'Stick!',
#   'Don’t!',
#   'Yeah,',
#   'The',
#   '[Monkey',
#   '[laughs]',
#   'Oh!',
#   'Agh!',
#   'Hey,',
#   '[yelps]'],
#  'sighs]': ['[monkey', '[Dragon', '…suffer', '[Lin', '[Lin'],
#  'A': ['wise',
#   'monkey',
#   'living',
#   '100-person',
#   'guitar.',
#   'graveyard?',
#   'duel.',
#   'rock?',
#   'rogue',
#   'servant.',
#   'human',
#   'pinch',
#   'spoonful',
#   'spoonful',
#   'drop',
#   'freak'],
#  'wise': ['monkey'],
#  'never': ['stretches',
#   'be',
#   'accept',
#   'heard',
#   'heard',
#   'seen',
#   'talked',
#   'will',
#   'lets',
#   'gonna',
#   'amount',
#   'be',
#   'end.',
#   'be',
#   'be',
#   'left'],
#  'stretches': ['beyond'],
#  'beyond': ['his'],
#  'grasp.': ['[grunts]'],
#  '[grunts]': ['[sighs]',
#   'Ha!',
#   'Huh?',
#   '[groans',
#   '[rock',
#   'Pew!',
#   '[rock',
#   '[man]',
#   '[Mayor’s',
#   'Ha',
#   'Itching!',
#   '[laughs]',
#   'Dragon',
#   'Are',
#   '[screams]',
#   'This',
#   '[Monkey',
#   'Yeah,',
#   '[Monkey',
#   'Don’t',
#   'Okay,',
#   'A',
#   'Right.',
#   '[both',
#   '[Monkey',
#   'This',
#   '[gentle'],
#  '[sighs]': ['[elder',
#   'So,',
#   'I',
#   'Trees.',
#   'This',
#   'Wow.',
#   '[Wangmu]',
#   'Does',
#   'What',
#   '[groans]'],
#  '[elder': ['monkey',
#   'monkey',
#   'monkey',
#   'monkey]',
#   'monkey',
#   'monkey]',
#   'monkey]',
#   'monkey'],
#  'Will': ['you', 'be'],
#  'let': ['go?',
#   'it',
#   'me',
#   'go!',
#   'them',
#   'him',
#   'them.',
#   'anyone,',
#   'him',
#   'this'],
#  'go?': ['[monkey', '[Stick'],
#  'laughs]': ['Ow!',
#   '[screeching]',
#   'Whoa!',
#   '[demon',
#   '[exciting',
#   'Hey,',
#   '[Mayor',
#   '[Red',
#   'Creepy.',
#   'Boom!',
#   'Hm.',
#   '[Monkey',
#   'Ow!',
#   'And',
#   '[Yama',
#   '[Lin]',
#   'No.',
#   '[Monkey',
#   'Huh?',
#   'No,',
#   'Goodbye,',
#   'That',
#   'Are',
#   '[dramatic',
#   'Salutations,',
#   'Stop',
#   '[dramatic',
#   'Fry',
#   'Jia',
#   '[Dragon',
#   '[Yama',
#   '[Monkey',
#   'Monkey!',
#   'Monkey!',
#   '[Lin]',
#   '[exciting',
#   '[Stick',
#   'Are',
#   'Come'],
#  'Ow!': ['Ah.',
#   '[Stick',
#   'What',
#   'Oh',
#   '[Red',
#   'Uh-oh.',
#   '[Stick',
#   'That',
#   'Hey,',
#   'Those'],
#  'Ah.': ['Huh?', '[demon'],
#  'Huh?': ['As',
#   '[growling',
#   '[rock',
#   '[tense',
#   '[monkey',
#   'Whoa!',
#   'Anyone',
#   'Monkey',
#   'Where',
#   '[Stick',
#   'Hee-yah!',
#   'You',
#   '[Dragon',
#   '[Monkey',
#   'Hey!',
#   '[Stick',
#   'What',
#   '[mysterious',
#   '[Monkey',
#   '[Monkey',
#   'Monkey!',
#   'Where’s',
#   '[Monkey',
#   'Oh'],
#  'As': ['I', 'my', 'soon'],
#  'saying,': ['if'],
#  'if': ['the', 'we', 'all', 'my', 'I', 'you', 'you'],
#  'coconut': ['is'],
#  'meant': ['for', 'for'],
#  'will': ['be',
#   'die.',
#   'unleash',
#   'end',
#   'crown?',
#   'eat',
#   'the',
#   'impress',
#   'learn',
#   'suffer',
#   'we',
#   'be',
#   'we',
#   'be.',
#   'give',
#   'your',
#   'end',
#   'see',
#   'never',
#   'never',
#   'deny',
#   'reign',
#   'reign',
#   'address',
#   'be',
#   'do',
#   'have',
#   'need',
#   'crown?',
#   'deny',
#   'not'],
#  'be': ['within',
#   'some',
#   'one',
#   'wielded',
#   'an',
#   'demon',
#   'a',
#   'famous.',
#   'a',
#   'right',
#   'here?',
#   'the',
#   'more',
#   'neighbors.',
#   'attained',
#   'manipulative,',
#   'in',
#   'more',
#   'critical,',
#   'fair.',
#   'from',
#   'found',
#   'one',
#   'satisfied.',
#   'fulfilled.',
#   'your',
#   'happy,',
#   'sad.',
#   'the',
#   'calling',
#   'yours',
#   'in',
#   'written.',
#   'back',
#   'loved.',
#   'out',
#   'water',
#   'the',
#   'published.'],
#  'within': ['reach.'],
#  'reach.': ['Mm.'],
#  'Mm.': ['Not'],
#  'Not': ['today.',
#   'happening.',
#   'me.',
#   'that',
#   'a',
#   'my',
#   'heck.',
#   'so',
#   'the',
#   'yours!',
#   'possible.',
#   'until',
#   'interested!',
#   'fair!'],
#  'today.': ['Oh!'],
#  '[monkeys': ['gasp]',
#   'laugh]',
#   'giggle]',
#   'screech]',
#   'whimper]',
#   'gasp]',
#   'chanting]',
#   'murmur]',
#   'cheer]'],
#  'gasp]': ['Out', '[monkey]'],
#  'Out': ['of', 'of'],
#  'light!': ['[monkey', '[suspenseful'],
#  'groans]': ['[monkeys',
#   'Ow!',
#   'Huh?',
#   'Stick?',
#   'Okay,',
#   'Try',
#   '…is',
#   '[metal',
#   '[Monkey',
#   'Whatever',
#   'Uh-oh.',
#   '[suspenseful',
#   'Where',
#   'That',
#   'Agh!',
#   '[groans]',
#   'You',
#   '[Monkey',
#   '[Monkey',
#   'Show',
#   'You',
#   'Maybe',
#   'Gotcha!',
#   'This',
#   '[dramatic',
#   '[Monkey',
#   'No!'],
#  'laugh]': ['[elder', '[henchmen', '[soft', '[Monkey'],
#  'growls]': ['No,',
#   '[monkeys',
#   'Huh?',
#   '[baby',
#   'Ha',
#   'I,',
#   '[Stick',
#   '[monkey',
#   '[Stick',
#   'Oh!',
#   'Monkey?',
#   '[Monkey',
#   'Here',
#   'I',
#   'This',
#   'It’s',
#   'Please,'],
#  'No,': ['no,',
#   'no,',
#   'I',
#   'no,',
#   'I',
#   'no,',
#   'wait,',
#   'no,',
#   'not',
#   'no,',
#   'you',
#   'you',
#   'no,',
#   'I',
#   'no,',
#   'not',
#   'we',
#   'I’m',
#   'Monkey!',
#   'no,',
#   'no,'],
#  'no,': ['no,',
#   'no!',
#   'no.',
#   'no,',
#   'no,',
#   'no.',
#   'no,',
#   'no,',
#   'no,',
#   'no,',
#   'no!',
#   'no.',
#   'no,',
#   'no.',
#   'no,',
#   'no.',
#   'no!',
#   'not',
#   'no,',
#   'no,',
#   'no!',
#   'no,',
#   'no,',
#   'no!'],
#  'no!': ['We',
#   'Any',
#   '[henchmen',
#   'Monkey!',
#   '[gasps',
#   '[grunts]',
#   'Monkey!',
#   'No!',
#   'No!',
#   '[laughs]'],
#  'live': ['in', 'without', 'chicken'],
#  'world': ['of',
#   'has',
#   'has',
#   'of',
#   'domination',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   '♪',
#   'will',
#   'needs',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'love',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'sub-marine',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'by',
#   'from'],
#  'order.': ['Oh?'],
#  'Oh?': ['Observe.'],
#  'Observe.': ['Think'],
#  'Think': ['of'],
#  'palm': ['as'],
#  'as': ['our',
#   'a',
#   'your',
#   'I’d',
#   'I',
#   'useless',
#   'I',
#   'you',
#   'juicy',
#   'the',
#   'the',
#   'Buddha]',
#   'Buddha]',
#   'Buddha]',
#   'Buddha]',
#   'it'],
#  'our': ['universe.',
#   'conquest',
#   'town.”',
#   'fiery',
#   'suffering.',
#   'monkey',
#   'hero',
#   'journey'],
#  'Compared': ['with'],
#  'with': ['this',
#   'the',
#   'that',
#   'them!',
#   'or',
#   'a',
#   'a',
#   'open',
#   'gold?',
#   'sharks.',
#   'that',
#   'you!',
#   'a',
#   'me,',
#   'this',
#   'me?',
#   'the',
#   'you.',
#   'that?',
#   'peace',
#   'the',
#   'Ricky,'],
#  'this': ['greatness,',
#   'minute!',
#   'grand',
#   'part',
#   'to',
#   'is',
#   'person.',
#   'guy',
#   'fire',
#   'time',
#   'chump?',
#   'tiny',
#   'is',
#   'is',
#   'up.',
#   'stolen',
#   'is',
#   'look',
#   'is…',
#   'magic',
#   'magic',
#   'tree.',
#   'one?',
#   '“we”?',
#   'room',
#   'place?',
#   'time.',
#   'un-phibian',
#   'happen.',
#   'is',
#   'plan?',
#   'un-phibian'],
#  'greatness,': ['one'],
#  'little': ['monkey',
#   'smaller,',
#   'child!',
#   'girl.',
#   'scrawny',
#   'flat.',
#   'minx',
#   'girl.',
#   'snack.',
#   'thing?',
#   'show',
#   'stinger!',
#   'girl.',
#   'monkey.',
#   'respect.',
#   'monkey',
#   'monkey',
#   'pebble'],
#  'insignificant': ['pebble.', 'pebble.', 'pebble?'],
#  'pebble.': ['Only', 'Even', 'Stop', 'All', '[Lin'],
#  'Only': ['the', 'your', 'endless'],
#  'are': ['free',
#   'no',
#   'looked',
#   'over!',
#   'the',
#   'incredible!',
#   'you?',
#   'you',
#   'you?',
#   'you',
#   'ripest',
#   'the',
#   'no',
#   'you',
#   'talking.',
#   'they',
#   'you',
#   'dying.',
#   'so',
#   'crazy!',
#   'the',
#   'the',
#   'the',
#   'juiciest',
#   'gorgy!',
#   'good',
#   'my',
#   'you',
#   'we',
#   'the',
#   'alone.',
#   'counting',
#   'we?',
#   'you',
#   'you?',
#   'they',
#   'fates',
#   'meant',
#   'powerful',
#   'now',
#   'marked'],
#  'free': ['to', 'its', 'guitar'],
#  'without': ['rules.', 'Stick,'],
#  'rules.': ['Know', 'Me'],
#  'Know': ['your'],
#  'place,': ['young'],
#  'young': ['one.', 'ones.', 'man'],
#  'one.': ['Oh!',
#   'I',
#   'Oh.',
#   '[Dragon',
#   '[laughs]',
#   'Hit',
#   'Ugh.',
#   'Nectar',
#   'I’m',
#   'I’m'],
#  '[young': ['monkeys'],
#  'monkeys': ['screech]', 'are'],
#  'screech]': ['[monkey', '[monkeys'],
#  '[screeching]': ['[elder', 'Whoa!', '[Monkey'],
#  'monkey]': ['Come', 'Come.', 'Absurd!'],
#  'Come': ['back',
#   'back!',
#   'on!',
#   'back,',
#   'on!',
#   'on,',
#   'on,',
#   'on!',
#   'on.',
#   'on.',
#   'on!',
#   'on.',
#   'on.',
#   'on,',
#   'on.',
#   'on,',
#   'on.',
#   'on,'],
#  'back': ['here',
#   'there,',
#   'to',
#   'home.',
#   'in',
#   'for',
#   'for',
#   '‘Cause',
#   'by',
#   'at',
#   '‘Cause'],
#  'here': ['right',
#   'since',
#   'and',
#   'is',
#   'I',
#   'they',
#   'I',
#   'to',
#   'amongst',
#   'had',
#   'on',
#   'for',
#   'for'],
#  'right': ['this',
#   'up.',
#   'into',
#   'back.',
#   'above',
#   'stick?',
#   'in',
#   'now!',
#   'way',
#   'tree.'],
#  'minute!': ['Out'],
#  'giggle]': ['Come'],
#  'back!': ['[growling]', 'It’s', 'Don’t', 'Don’t'],
#  '[growling]': ['Huh?'],
#  '[growling': ['continues]'],
#  'continues]': ['[creature',
#   '[grunts]',
#   'Ha!',
#   'Hm.',
#   'Ha',
#   'You’ve',
#   '[column',
#   '[monkey',
#   'Wave',
#   '[Monkey',
#   'Bad',
#   'Stick,',
#   '[grunts]',
#   '[grunting]',
#   '[grunts]',
#   '[Lin',
#   'Well,',
#   '[uplifting',
#   '[Monkey',
#   'Yes!',
#   '[Monkey',
#   'Okay,',
#   '[Monkey',
#   'Woo-hoo!',
#   'Whoa!',
#   '[uplifting',
#   'Thank',
#   'I’ll',
#   'Oh.',
#   '[Lin',
#   '[Lin]'],
#  '[creature': ['roars]'],
#  'roars]': ['Run!', '[monkey', 'Bad'],
#  'Run!': ['The', '[sighs]'],
#  'The': ['demon',
#   'reptile',
#   'overboard',
#   'Dragon',
#   'days',
#   'outsider’s',
#   'ultimate',
#   'girl?',
#   'fire',
#   'quicker',
#   'demon',
#   'Monkey',
#   'Immortal',
#   'stick',
#   'grown-ups',
#   'villain',
#   'scrolls',
#   'Book',
#   'sooner',
#   'hills?',
#   'desert?',
#   'toxin',
#   'one',
#   'one',
#   'tree',
#   'three',
#   'queen',
#   'first',
#   'blue',
#   'green',
#   'Jade',
#   'original',
#   'Dragon',
#   'Dragon',
#   'world?',
#   'Dragon',
#   'Buddha',
#   'biggest',
#   'ultimate',
#   'Monkey',
#   'team',
#   'Buddha',
#   'world',
#   'hurricane',
#   'world'],
#  'demon': ['is',
#   'situation,',
#   'dumplings.',
#   'will',
#   'of',
#   'was',
#   'vanquished!',
#   '101.',
#   'dragon’s'],
#  'here!': ['Oh.', 'See,', 'Coming', '[Lin]', 'What'],
#  '[gasps': ['and', 'and'],
#  'whimper]': ['[sad'],
#  '[sad': ['music', 'music'],
#  'cries]': ['Your'],
#  'recklessness': ['drew'],
#  'drew': ['the'],
#  'Demon': ['of', 'of', 'Slayer.'],
#  'Havoc': ['upon'],
#  'upon': ['us.', 'by'],
#  'us.': ['You', 'You’re', '[Stick', 'Unless', 'How', 'Actually,', 'Huh?'],
#  'You': ['don’t',
#   'again?',
#   'fool!',
#   'think',
#   'talk?',
#   'are',
#   'handle',
#   'let',
#   'got',
#   'know',
#   'are',
#   'know',
#   'never',
#   'love',
#   'missed!',
#   'see',
#   'can’t',
#   'killed',
#   'brought',
#   'abandoned',
#   'don’t',
#   'don’t',
#   'can’t',
#   'don’t.',
#   'shut',
#   'got',
#   'didn’t',
#   'had',
#   'must',
#   'sure',
#   'need',
#   'are',
#   'eat',
#   'eat',
#   'eat',
#   'are',
#   'must',
#   'idiot!',
#   'awake?',
#   'said',
#   'did.',
#   'know',
#   'think',
#   'know',
#   'only',
#   'too,',
#   'got',
#   'are',
#   'have',
#   'can’t',
#   'call',
#   'couldn’t',
#   'will',
#   'came',
#   'came',
#   'care.',
#   'could',
#   'wanna',
#   'can',
#   'want',
#   'said',
#   'betrayed',
#   'see,',
#   'did',
#   'defeated',
#   'shall',
#   'could',
#   'will',
#   'never',
#   'tricked',
#   'changed'],
#  'don’t': ['belong',
#   'belong',
#   'think',
#   'know',
#   'let',
#   'hit',
#   'see',
#   'need',
#   'die.',
#   'leave',
#   'belong',
#   'have',
#   'let',
#   'know',
#   'feel',
#   'do',
#   'drink',
#   'know,',
#   'know.',
#   'let',
#   'ask.',
#   'ask.',
#   'mention',
#   'have',
#   'go'],
#  'belong': ['here,', 'here.', 'with', 'here,'],
#  'here,': ['outsider!', 'outsiders.'],
# ...
#  'again.': ['[monkeys'],
#  'murmur]': ['Best'],
#  'Best': ['weapons?'],
#  'weapons?': ['Uh-huh.'],
#  'Uh-huh.': ['Very', 'We’re'],
#  'much': ['us.', 'from', 'reading', 'harder'],
#  'right.': ['I', '[scoffs]', 'One', 'Next!', 'Moving', 'Got', 'Come'],
#  'here.': ['I',
#   '[ominous',
#   'Ha!',
#   'Water',
#   'How',
#   'No',
#   'That’s',
#   '[Lin',
#   'Ha'],
#  'them!': ['[monkeys', 'Uh,', '[clone'],
#  'cheer]': ['[monkeys]'],
#  '[monkeys]': ['Monkey'],
#  'They’d': ['never'],
#  'accept': ['the', 'me.', 'the'],
#  'likes': ['of'],
#  'conquered': ['a'],
#  'demon.': ['You’d', 'Huh?'],
#  'You’d': ['have', 'better'],
#  'defeat': ['a', 'me?', 'demon', 'him.'],
#  'hundred': ['demons', 'demons', 'demons.', 'demons'],
#  'demons': ['to',
#   'coming',
#   'screaming',
#   'down.',
#   'screaming',
#   'defeated.',
#   'run',
#   'screaming'],
#  'even': ['get',
#   'come',
#   'wears',
#   'supposed',
#   'feel',
#   'the',
#   'supposed',
#   'mean?'],
#  'their': ['attention.', 'door?', 'door?', 'ruler,', 'door?', 'home'],
#  'attention.': ['Oh', '[Lin'],
#  'yeah.': ['[elder', 'Great.', 'You', 'So', 'One'],
#  'scoffs]': ['I', 'How'],
#  'suppose': ['you’re'],
#  'Of': ['course', 'course!', 'course.', 'course', 'this', 'the'],
#  'course': ['I’m', 'I', 'I'],
#  'up!': ['[heavy'],
#  '[heavy': ['metal', 'metal'],
#  'metal': ['music', 'music'],
#  '[Monkey': ['King]',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King]',
#   'King]',
#   'King]',
#   'King',
#   'King]',
#   'King]',
#   'King]',
#   'King]',
#   'cackles]',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King]',
#   'King]',
#   'King]',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King]',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'squeals]',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King]',
#   'King]',
#   'King]',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King]',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King',
#   'King]',
#   'King'],
#  'Uh-oh.': ['Agh!',
#   'The',
#   'Ow!',
#   'Stick!',
#   'That',
#   'Hey,',
#   '[Lin',
#   '[grunts]',
#   '[laughs]',
#   '[panting]',
#   'Sir,'],
#  'Agh!': ['[screeching]',
#   'My',
#   'Fear',
#   '[dramatic',
#   'Wait!',
#   'Gee,',
#   'No!',
#   'Agh!',
#   '[dramatic',
#   '[Monkey',
#   'Whoa!'],
#  'gasps': ['and', 'and', 'and'],
#  'grunts': ['and', 'and', 'and'],
#  '♪': ['Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'And',
#   '♪',
#   'He’s',
#   '♪',
#   'Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'And',
#   '♪',
#   'That’s',
#   '[Monkey',
#   'Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'And',
#   '♪',
#   'That’s',
#   'Eh,',
#   'Who’s',
#   '♪',
#   'Monkey',
#   'Man,',
#   'Behold',
#   '♪',
#   'Full',
#   '♪',
#   'It’s',
#   '♪',
#   'We',
#   '♪',
#   'And',
#   '♪',
#   'Which',
#   'I',
#   'Ha,',
#   '♪',
#   'We',
#   '♪',
#   'Of',
#   '♪',
#   'We',
#   '♪',
#   'So',
#   '♪',
#   'I',
#   '[Benbo',
#   'Hopefully',
#   'Stand',
#   'Feeling',
#   '♪',
#   'Trust',
#   '♪',
#   'You',
#   '♪',
#   'That',
#   '♪',
#   'Whenever',
#   '♪',
#   'In',
#   '♪',
#   'So',
#   '♪',
#   'Forever',
#   '♪',
#   'But',
#   '♪',
#   'There’s',
#   '♪',
#   'Why',
#   '♪',
#   'Second-rate',
#   '♪',
#   'To',
#   '♪',
#   'So',
#   '♪',
#   'And',
#   '♪',
#   'I’ll',
#   '♪',
#   'He’s',
#   'Yes,',
#   'For',
#   '♪',
#   'Now',
#   '♪',
#   'And',
#   '♪',
#   'No',
#   '♪',
#   'Benbo,',
#   '♪',
#   'Only',
#   '♪',
#   'Benbo,',
#   '[Dragon',
#   'No',
#   '♪',
#   'And',
#   '♪',
#   'No',
#   '♪',
#   'No',
#   '♪',
#   'No',
#   '♪',
#   'No',
#   '♪',
#   'Drying',
#   '[voice',
#   'Note',
#   '♪',
#   'Ever',
#   '♪',
#   'So',
#   '♪',
#   'Open',
#   '♪',
#   'And',
#   '♪',
#   'I’m',
#   '♪',
#   'And',
#   '♪',
#   'No,',
#   '♪',
#   'Fortune',
#   '♪',
#   'So,',
#   '♪',
#   'So',
#   '♪',
#   'So',
#   '♪',
#   'Our',
#   '[Dragon',
#   'Open',
#   '♪',
#   'He’s',
#   '♪',
#   'And',
#   '♪',
#   'By',
#   '[villagers',
#   'Who’s',
#   'I',
#   'Monkey',
#   '♪',
#   'Who',
#   'Please,',
#   'Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'And',
#   '♪',
#   'He’s',
#   '♪',
#   'Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Who’s',
#   '♪',
#   'And',
#   '♪',
#   'That’s',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '♪',
#   'Monkey',
#   '[Dragon',
#   'So',
#   '♪',
#   'Open',
#   '♪',
#   'And',
#   '♪',
#   'I’ll',
#   '♪',
#   'And',
#   '[Babbo',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '[Benbo]',
#   'Dragon',
#   '[Babbo]',
#   'The',
#   '♪',
#   'He’ll',
#   '♪',
#   'It’s',
#   '♪',
#   'It’s',
#   '♪',
#   'We’re',
#   '[Benbo]',
#   'Monkey',
#   '[Babbo]',
#   'We',
#   '[Benbo]',
#   'And',
#   '[Babbo]',
#   'We’re',
#   '[Benbo]',
#   'Time',
#   '[Babbo]',
#   'And',
#   '[Benbo]',
#   'His',
#   '[Babbo]',
#   'He',
#   '[both]',
#   'Ha',
#   '[Babbo]',
#   'And',
#   '[Benbo]',
#   'We',
#   '[both]',
#   'When',
#   '[Dragon',
#   'So',
#   '♪',
#   'And',
#   '♪',
#   'I’ll',
#   '♪',
#   'And',
#   '♪',
#   'Every',
#   '♪',
#   'Every',
#   '♪',
#   'Will',
#   '♪',
#   'So',
#   '♪',
#   'And',
#   '[Benbo',
#   'He’ll',
#   '♪',
#   'He’ll',
#   '♪',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '[Dragon',
#   'I',
#   '♪',
#   'And',
#   '♪',
#   'I',
#   '♪',
#   'Now',
#   '♪',
#   'This',
#   '[Benbo',
#   'Oh',
#   '[Benbo]',
#   'And',
#   '[Babbo]',
#   'We’re',
#   '[Benbo]',
#   'Time',
#   '[Babbo]',
#   'And',
#   '[Benbo]',
#   'His',
#   '[Babbo]',
#   'He',
#   '[both]',
#   'Ha',
#   '[Babbo]',
#   'And',
#   '[Benbo]',
#   'We',
#   '[both]',
#   'When',
#   '[Dragon',
#   'So',
#   '♪',
#   'And',
#   '♪',
#   'I’ll',
#   '♪',
#   'And',
#   '♪',
#   'I’m',
#   '♪',
#   'To',
#   '♪',
#   'To',
#   '♪',
#   'Name-calling,',
#   '♪',
#   'Embarrassing-me-in-front-of-my-friends',
#   '♪',
#   'I',
#   '♪',
#   'They’re',
#   '♪',
#   'So',
#   '♪',
#   'And',
#   '♪',
#   'I’ll',
#   '♪',
#   'And',
#   '♪',
#   'For',
#   '♪',
#   'Now',
#   '♪',
#   'And',
#   '♪',
#   'When',
#   '[Benbo',
#   'Hey,',
#   '♪',
#   'He’ll',
#   '♪',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '♪',
#   'Hey,',
#   '[mysterious'],
#  'Who’s': ['the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this',
#   'that?',
#   'gonna',
#   'Lin?',
#   'the',
#   'the',
#   'a',
#   'the',
#   'the',
#   'the'],
#  'handsome': ['hero', 'artist', 'hero', 'hero', 'hero'],
#  'hero': ['We', 'here.', 'meetup.', 'the', 'We', 'We', 'going', 'We'],
#  'adore?': ['♪', '♪', '♪', '♪'],
#  'Who': ['has',
#   'is',
#   'are',
#   'has',
#   'are',
#   'even',
#   'wants',
#   'wants',
#   'is',
#   'can',
#   'has',
#   'is'],
#  'screaming': ['When', 'When', 'When'],
#  'When': ['he',
#   'he',
#   'he',
#   'it’s',
#   'we',
#   'I',
#   'you',
#   'he',
#   'he',
#   'he',
#   'it',
#   'it',
#   'I',
#   'the'],
#  'knocks': ['on', 'on', 'on'],
#  'door?': ['♪', '♪', '♪'],
#  'mighty': ['fighter', 'Monkey', 'Dragon', 'fighter'],
#  'fighter': ['Who', 'Who'],
#  'brave': ['and', '♪', 'and'],
#  'spunky': ['♪', '♪'],
#  'also': ['a', 'a', 'a'],
#  'bit': ['of', 'of'],
#  'hunk?': ['♪', '♪'],
#  'ape': ['you', 'didn’t', 'you'],
#  'escape': ['When', 'When'],
#  'hunts': ['you', 'you'],
#  'down?': ['♪', '[laughs]', '♪'],
#  'chimp': ['All', 'All'],
#  'All': ['the', 'right.', 'you', 'right,', 'the', 'rights'],
#  'simple': ['people', 'people'],
#  'people': ['will', 'alone.', 'are', 'tell', 'will'],
#  'crown?': ['♪', '♪'],
#  'simian': ['you’ll', 'you’ll', 'you’ll'],
#  'you’ll': ['find', 'find', 'see.', 'get', 'get', 'always', 'find'],
#  'shimmying': ['Up', 'Up', 'Up'],
#  'Up': ['to', 'to', 'to'],
#  'top': ['♪', '♪', 'speed?', 'speed.', 'dragon', 'of', '♪'],
#  'know': ['he',
#   'everyone!',
#   'us.',
#   'it’s',
#   'this',
#   'it.',
#   'he',
#   'what',
#   'this',
#   'when',
#   'we',
#   'you’ll',
#   'why,',
#   'you.',
#   'what?',
#   'what?',
#   'who’s',
#   '♪',
#   'you’re',
#   'he'],
#  'won’t': ['stop',
#   'you',
#   'stop',
#   'even',
#   'let',
#   'ever',
#   'you',
#   'stop',
#   'get',
#   'get'],
#  'stop': ['Till', 'that!', 'Till', 'me?', 'him.', 'a', 'Till'],
#  'Till': ['he’s', 'he’s', 'he’s'],
#  'he’s': ['won?', 'won?', 'got', 'come', 'not', 'not', 'won?', 'the'],
#  'won?': ['♪', '♪', '♪'],
#  'right,': ['it’s', 'it’s', 'Stick?', 'Benbo,', 'he’s'],
#  'Ninety-nine': ['demons'],
#  'down.': ['One', 'Hey!'],
#  'go.': ['Hey,', 'Oh!', 'You', '[Wangmu]'],
#  'Hey,': ['hero',
#   'hey,',
#   'Red',
#   'cut',
#   'you’re',
#   'stop',
#   'you',
#   'hey,',
#   'Babbo,',
#   'are',
#   'uh,',
#   'do',
#   'I',
#   'hey,',
#   'don’t',
#   'Lin.',
#   'Lin,',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey',
#   'hey'],
#  '[ominous': ['rattling]', 'rattling]', 'music'],
#  'rattling]': ['Once-in-a-lifetime', 'Where'],
#  'Once-in-a-lifetime': ['hero'],
#  'meetup.': ['[ominous'],
#  'everyone?': ['[girl'],
#  '[girl': ['gasps]', 'scoffs]'],
#  'Anyone': ['need'],
#  '[woman': ['1]', '2]'],
#  'Go': ['away!', 'ahead.', 'on.', 'home.', 'away!'],
#  'Leave': ['us'],
#  'us': ['alone!',
#   'killed!',
#   'alone.',
#   'how',
#   'with',
#   'rain?',
#   'Immortal',
#   'to'],
#  'alone!': ['[man]', '[Lin'],
#  '[man]': ['You’ll', 'Come'],
#  'killed!': ['Name’s'],
#  'Name’s': ['Monkey'],
#  'AKA': ['the', 'the'],
#  'Simian': ['Savior.'],
#  'Savior.': ['AKA'],
#  'Legendary': ['Demon'],
#  'Slayer.': ['And'],
#  'Our': ['amazing', 'crops', 'quest', 'king'],
#  'amazing': ['skills'],
#  'skills': ['include', 'as'],
#  'include': ['pole-fighting,'],
#  'pole-fighting,': ['punching,'],
#  'punching,': ['kicking,'],
#  'kicking,': ['a'],
#  'kick-pole': ['punch'],
#  'punch': ['combo,'],
#  'combo,': ['the'],
#  'double-kick': ['with'],
#  'or': ['without',
#   'the',
#   'I',
#   'skewers?',
#   'what?',
#   'chopsticks',
#   'stand',
#   'a'],
#  'ever-popular': ['fake'],
#  'fake': ['kick'],
#  'kick': ['with', 'off'],
#  'spinning': ['pole.'],
#  'pole.': ['[Monkey'],
#  'Huh!': ['Yeah!'],
#  'Yeah!': ['[girl]', '“How', 'Monkey', 'Knock'],
#  '[girl]': ['Huh?', 'Hm.'],
#  'King?': ['I’ve', 'What’s', '[Lin]', 'My'],
#  'I’ve': ['never', 'never', 'never', 'got', 'realized', 'created'],
#  'heard': ['of', 'of', 'that'],
#  'either.': ['[Stick'],
#  'village': ['needs', 'who', 'from', 'by', 'is', 'the'],
#  'needs': ['one', 'to', 'to', 'us.'],
#  'fancy': ['stick.', 'peach'],
#  'dump': ['counts'],
#  'counts': ['as'],
#  'village?': ['Come'],
#  'gonna': ['make',
#   'be',
#   'burn',
#   'get',
#   'fit',
#   'be',
#   'share',
#   'be',
#   'buy',
#   'get',
#   'join',
#   'stop',
#   'do?',
#   'make',
#   'perform',
#   'feel',
#   'be',
#   'die',
#   'perform'],
#  'make': ['it', 'it', 'a', 'a', 'a', 'me', 'a', 'a', 'you', 'my', 'a', 'it'],
#  'worse.': ['[scoffs]'],
#  'thanks': ['for', 'for', 'to'],
#  'stopping': ['by.'],
#  'by.': ['I'],
#  'how': ['great', 'will', 'do', 'exactly', 'I', 'do'],
#  'great': ['I', 'news.', 'things.', 'things.'],
#  'am…': ['He’s'],
#  'real': ['deal,', '♪', 'peach'],
#  'deal,': ['folks.'],
#  'folks.': ['A'],
#  'living': ['legend.', 'things', 'things'],
#  'legend.': ['I'],
#  'am?': ['I'],
#  'am.': ['If', 'Crossed'],
#  'you’ve': ['got'],
#  'situation,': ['this'],
#  'guy.': ['Huh?', 'Hey!'],
#  'come': ['from,', 'get', 'on.', 'on.', 'on.', 'home.', 'up'],
#  'from,': ['kid?'],
#  'kid?': ['I’ve', 'What'],
#  'seen': ['her'],
#  'her': ['before,', 'to', 'laboratory', 'famous', 'new'],
#  'before,': ['and'],
#  'mayor’s': ['wife.'],
#  'wife.': ['I'],
#  'everyone!': ['You’d'],
#  'better': ['get', 'than', 'attention.'],
#  'Unless': ['you'],
#  'wanna': ['be', 'do', 'be'],
#  'dumplings.': ['Aiya.'],
#  'Aiya.': ['Okay.'],
#  'Okay.': ['Whisper', 'Next', 'If', 'Uh,', 'I', 'If', 'How', 'Okay.', 'We'],
#  'Whisper': ['time.'],
#  'Maybe': ['the',
#   'you’re',
#   'I',
#   'it’s',
#   'I',
#   'you',
#   'they’re',
#   'defeating',
#   'you’d'],
#  'eat': ['the', 'a', 'it.', 'it.', 'it', 'it.', 'it.', 'it.'],
#  'monkey.': ['And', 'No', '[Monkey'],
#  'Either': ['way,'],
#  'way,': ['we'],
#  'win.': ['Oh,'],
#  'Break!': ['Brave'],
#  'Brave': ['warrior.'],
#  'warrior.': ['My'],
#  'poor,': ['dear', 'unattractive'],
#  'dear': ['child'],
#  'child': ['was'],
#  'kidnapped.': ['Every'],
#  'Every': ['rainy', 'inch', 'part'],
#  'rainy': ['season,'],
#  'season,': ['the'],
#  'horrible': ['fire'],
#  'fire': ['beast', 'beast', 'demon,'],
#  'beast': ['descends…', 'is'],
#  'descends…': ['Fire'],
#  'Fire': ['beast?'],
#  'beast?': ['That’ll'],
#  'That’ll': ['be'],
#  'demons.': ['[Stick'],
#  'in.': ['Okay,', 'Chamber'],
#  'desperate': ['peasants.'],
#  'peasants.': ['Where’s'],
#  'Where’s': ['he', 'my', 'that?', 'Stick?', 'my'],
#  'going?': ['Let’s'],
#  'Let’s': ['talk', 'go.', 'go', 'go!'],
#  'talk': ['about'],
#  'about': ['my',
#   'you,',
#   'my',
#   'is',
#   'at',
#   'yourself.',
#   'you.',
#   'me.',
#   'I',
#   'I',
#   'two',
#   'it.'],
#  'ascension': ['ceremony.', 'to'],
#  'ceremony.': ['Ascension', 'Point'],
#  'Ascension': ['ceremony?'],
#  'ceremony?': ['Your'],
#  'party.': ['How'],
#  'else': ['will', 'will.'],
#  'time': ['to', 'of', 'to', 'back'],
#  'I’ll': ['need',
#   'give',
#   'do',
#   'just',
#   'show',
#   'grab',
#   'take',
#   'do',
#   'just',
#   'take',
#   'become',
#   'never',
#   'never',
#   'help',
#   'show',
#   'flood',
#   'tell',
#   'think',
#   'be',
#   'miss',
#   'flood',
#   'flood',
#   'flood',
#   'flood'],
#  '35-piece': ['orchestra.'],
#  'orchestra.': ['No!'],
#  '100-person': ['dragon'],
#  'dragon': ['dance.', 'kingdom.', '♪'],
#  'dance.': ['No'],
#  'dancing.': ['And'],
#  'huge': ['fireworks'],
#  'fireworks': ['extravaganza.', 'shop!'],
#  'extravaganza.': ['My'],
#  'fireworks?': ['Too'],
#  'Too': ['expensive.', 'easy!'],
#  'expensive.': ['Unfortunately,'],
#  'Unfortunately,': ['ours'],
#  'ours': ['is'],
#  'but': ['a', 'we’ll', 'a', 'I', 'now', 'you’re', 'you'],
#  'poor': ['rice-farming', 'ignorant', 'village,', 'and'],
#  'rice-farming': ['village.'],
#  'village.': ['Yeah,', 'Come'],
#  'poor.': ['[girl'],
#  'insulting.': ['Come'],
#  'on,': ['King.', 'everyone.', 'Stick!', 'come', 'admit', 'but', 'Stick.'],
#  'walking.': ['Stop'],
#  'Stop': ['them!', 'calling', 'the', 'it!', 'wrecking', 'that,'],
#  'Uh,': ['uh…',
#   'name',
#   'uh,',
#   'um,',
#   'uh…',
#   'it',
#   'what’s',
#   'Dragon?',
#   'Monkey?',
#   'we’re',
#   'the'],
#  'uh…': ['Please,', 'You', 'You', 'It’s', '[sighs]'],
#  'Please,': ['won’t', 'you', 'he’s'],
#  'assistant': ['reconsider?', 'and', 'girl,', 'of', 'is'],
#  'reconsider?': ['Assistant?'],
#  'Assistant?': ['I'],
#  'person.': ['Who'],
#  'number': ['one', '100,', 'one'],
#  'fan.': ['I', 'Well,'],
#  'guy': ['took'],
#  'white': ['bone'],
#  'bone': ['demon,', 'demon,', 'demon'],
#  'demon,': ['the', 'and', 'the', 'old'],
#  'red': ['bone'],
#  'specific': ['color.'],
#  'color.': ['We'],
#  'sing': ['songs'],
#  'songs': ['about'],
#  'you,': ['and',
#   'demon.',
#   'sir,',
#   'gravity!',
#   'divine',
#   'a',
#   'you',
#   'little',
#   'Lin.',
#   'your',
#   'uh…',
#   'Great',
#   'you’d',
#   'and',
#   'Monkey.'],
#  'speech.': ['And?'],
#  'And?': ['Uh,', 'And?', 'Oh,'],
#  'name': ['a', 'is', 'should', 'off.', 'out'],
#  'street': ['after'],
#  'after': ['you?', 'his', 'a'],
#  'big,': ['fat'],
#  'fat': ['shiny'],
#  'shiny': ['medal'],
#  'medal': ['of'],
#  'solid': ['brass.'],
#  'brass.': ['Ooh,'],
#  'Ooh,': ['that', 'ooh.'],
#  'impress': ['’em.'],
#  '’em.': ['Okay.', '[Lin', 'This'],
#  'Next': ['up.'],
#  'What’s': ['in',
#   'in',
#   'a',
#   'wrong,',
#   'your',
#   'it',
#   'up,',
#   'it',
#   'next?',
#   'your',
#   'happening?'],
#  'trusty': ['companion?'],
#  'companion?': ['The'],
#  'girl?': ['No!'],
#  'wondrous': ['stick.'],
#  'him?': ['Um,', 'That'],
#  'Um,': ['what', 'done?', 'well,', 'it’s'],
#  'what': ['does', 'happens', 'if', 'a', 'does', 'I', 'you', 'I'],
#  'does': ['it', 'he', 'one', 'he?', 'it', 'it!', 'big!', 'care.', 'that'],
#  'want?': ['What', 'A'],
#  'guitar.': ['But', '[Stick'],
#  'stick': ['can’t',
#   'will',
#   'like',
#   'out',
#   'and…',
#   'and',
#   'and',
#   'for…',
#   'belongs',
#   '♪'],
#  'ten': ['free', 'seconds,'],
#  'guitar': ['lessons.'],
#  'lessons.': ['Um,'],
#  'done?': ['Done.', '‘Cause'],
#  'Done.': ['Hey,', '[roaring]'],
#  'hey,': ['hey,', 'hey.', 'hey,', 'hey.', 'you', 'hey'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(The_monkey_king_dict,100)
# Out:
# 'Oh! [monkeys gasp] [monkey] Hm. [Stick murmurs] Who’s a big one. I’m gonna buy this. Does this minute! Out of the right up. What’s it rain dance ♪ [both] ♪ Monkey King grunts] [Lin screams in the sun’s rays ♪ ♪ Monkey King? I’ve created a thief! Aw, you’re so exactly that stone monkey shrieks] [dramatic music continues] You’ve done good, girl. Go on. I’m starting to remind me. [Stick murmurs] I can welcome me A monkey squeals] Are in it work. Hai-yah! Agh! Agh! [dramatic music plays] [Stick groans] [groans] You’re so cares about you. He only a bath!.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
# 1. Generating Senetence for other TV Series:
for i in data.index:
    print(f"Generated text for {i}")
    x_text = data.transcript.loc[i]
    x_dict = build_markov_chain(x_text)
    print(generate_sentence(x_dict))
    print("\n")
# Out:
# Generated text for DESPICABLE ME 3
# Softly) (SPEAKING MINIONESE) (ALL GASP) Ooh, la-la! You boys have meant be kidding me. Pardon.
#
#
# Generated text for ELEMENTAL
# Side of his feet. Teeth. Whatever. Food upstairs. It might not up being modest. Ember’s.
#
#
# Generated text for KLAUS
# Mail, you care? – Go home, you think it’s your act of the mail, you.
#
#
# Generated text for THE BOSS BABY
# Privacy. Here at this time? (gasps) No, no. Don’t, don’t, don’t. Yes, first, they won’t.
#
#
# Generated text for THE MONKEY KING
# Unattractive people will end up ♪ Name-calling, life-ruining Loneliness-inducing ♪ ♪ And you so could’ve.

# %%
# generating sentence sequence of 100 words for each tv series.
for i in data.index:
    print(f"Generated text for {i}")
    x_text = data.transcript.loc[i]
    x_dict = build_markov_chain(x_text)
    print(generate_sentence(x_dict,100))
    print("\n")
# Out:
# Generated text for DESPICABLE ME 3
# Go tell you want. I make us unstoppable! Whoa! Ay, chihuahua! I can I should I can handle it. Well, now that I were such short notice. It is it! You’re making me about we can make a high note with me. (EXCLAIMS IN FRUSTRATION) (SINGING IN FRUSTRATION) (SINGING IN FRENCH) (CONTINUES LAUGHING) Oh, you and Gru and Gru loses! Enjoy the perfect idea. (AGNES CHEWING LOUDLY) BOTH: My turn! (GRUNTING) (BOTH LAUGH) Oh, come on. All right, lady, that’s pretty sure I just that poor little boys. (SIGHS) Okay, take good news! (SINGSONG) Ah! How about to an Emmy?.
#
#
# Generated text for ELEMENTAL
# Nice hat, by then, those doors. Water looks alike. You know where I sucked a mess. Nah. I guess. (CLANKS) Tempered glass. (SIGHS) Whew. So, uh, couldn’t go together You’re the show You need to embrace the shop? If you giving me across that city isn’t made me feel it. You don’t want to break my dad will lose temper, then you up. Still have to tell him though. Water, always right. (SMACKS LIPS) Actually, my dad passed, I no longer retire. (ALL GASP) And why I know where I lose my shift. (GRUNTS, GULPS) What are broken. This was….
#
#
# Generated text for KLAUS
# Locals to say your clan? – Come on. Really? Yeah, I… Of course I didn’t think she loved me. Dispatch for making… – Merry Christmas, Miss. Alva. Mogens. Come on! Get off! Isn’t this uniform? I can’t be some toys. Honest!” “Dear Mr. Klaus? Oh, no, no, no! Why don’t either, but most likely break my name! – Stop those words let you don’t, I’m not right. And cookouts! Brunches! Don’t answer that… Krums versus the worst! I’m going on record. Well, yeah, all up in a new workshop! – Look who’s counting? What? – Leave it out. I mean….
#
#
# Generated text for THE BOSS BABY
# Like, “F-minus. See the police. It’s, uh, stop coming sooner than a second chance. BabyCorp is coming for that message. (coos) On… purpose. I… TED: Woo-hoo! TIM (Southern accent): Well, how to spare. (distant explosion) Oh. Right. Whoa. How is so good at least not experts. After Tabitha and JANICE: Oh. Whoopsie. Your little klepto… Nighty night. Do it. Got your daughter’s school. Babies only. Oh, oh. (chuckles) With a week award. Wow. This bond is missing out ♪ ♪ It feels like we both grow up. (deep voice): Or there. Aw. Now, some privacy. Here you that there are.
#
#
# Generated text for THE MONKEY KING
# Itching! Flaking! [exciting music plays] [monkeys gasp] Out of a monkey never heard of Life and all alone. Hmm. [Stick murmurs] Woo-hoo! [Stick murmurs] Where did I said fine! [sighs] [elder monkey] Come back, Stick! [Stick groans] Gotcha! [grunts] [man] You’ll get away! [woman 2] Leave us to die is definitely not alone. [gentle music plays] [Monkey King giggles] I let it becomes clear to live in heaven and everything. [gentle music plays] Of the world from a weapon. Ha. From where? Oh, your scrolls? [laughs] [exciting music plays] Wow! [baby monkey ♪ And bury him in hell? What? Daddy!.

# %%
# Question no 2: modifying the generate_sentence function.
import random
import string 

def generate_sentence(chain, count=15 , punctuation = True):
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        if word2.endswith(tuple(string.punctuation)):
            sentence += ' ' + word2
            break
        else:
            sentence += ' ' + word2
            word1 = word2
        
        if punctuation:
            punctuation = random.choice(string.punctuation)
            sentence += punctuation
        else:
            sentence += "."

    return(sentence)
